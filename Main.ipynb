# %% [markdown]
# ### BIG DATA FINAL PROJECT

# %%
# !pip install pyspark
# !pip install pymongo
# !pip install pandas
# !pip install geopy
# !pip install folium
# !pip install haversine
# Out:
# Requirement already satisfied: pyspark in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (3.4.0)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: pymongo in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from pymongo) (2.3.0)
# Requirement already satisfied: pandas in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: geopy in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from geopy) (2.0)
# Requirement already satisfied: folium in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: haversine in /Users/utsavpatel/anaconda3/lib/python3.10/site-packages (2.8.0)

# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf

# create a SparkSession with increased memory allocation
conf = SparkConf() \
    .set("spark.driver.memory", "8g") \
    .set("spark.executor.memory", "8g") \
    .set("spark.network.timeout", "600s")

spark = SparkSession.builder \
    .appName("NYPD") \
    .config(conf=conf) \
    .getOrCreate()

# load the NYPD Complaints dataset into a Spark DataFrame
complaintsDF = spark.read.csv("NYPD_Complaint_Data_Historic.csv", header=True, inferSchema=True)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/09 01:09:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Only using half the dataset as its too big and taking too long and crashing sometimes on my PC
sampledDF = complaintsDF.sample(withReplacement=False, fraction=0.25, seed=42)

# %%
df = sampledDF

# %% [markdown]
# ## DATA PROFILING

# %%
df.printSchema()

# Display the number of rows and columns in the dataframe
print("Number of rows: ", df.count())
print("Number of columns: ", len(df.columns))

df.show(5)

# Display summary statistics of the dataframe
df.describe().show()
# Out:
# root
#  |-- CMPLNT_NUM: integer (nullable = true)
#  |-- CMPLNT_FR_DT: string (nullable = true)
#  |-- CMPLNT_FR_TM: timestamp (nullable = true)
#  |-- CMPLNT_TO_DT: string (nullable = true)
#  |-- CMPLNT_TO_TM: string (nullable = true)
#  |-- ADDR_PCT_CD: integer (nullable = true)
#  |-- RPT_DT: string (nullable = true)
#  |-- KY_CD: integer (nullable = true)
#  |-- OFNS_DESC: string (nullable = true)
#  |-- PD_CD: integer (nullable = true)
#  |-- PD_DESC: string (nullable = true)
#  |-- CRM_ATPT_CPTD_CD: string (nullable = true)
#  |-- LAW_CAT_CD: string (nullable = true)
#  |-- BORO_NM: string (nullable = true)
#  |-- LOC_OF_OCCUR_DESC: string (nullable = true)
#  |-- PREM_TYP_DESC: string (nullable = true)
#  |-- JURIS_DESC: string (nullable = true)
#  |-- JURISDICTION_CODE: integer (nullable = true)
#  |-- PARKS_NM: string (nullable = true)
#  |-- HADEVELOPT: string (nullable = true)
#  |-- HOUSING_PSA: string (nullable = true)
#  |-- X_COORD_CD: integer (nullable = true)
#  |-- Y_COORD_CD: integer (nullable = true)
#  |-- SUSP_AGE_GROUP: string (nullable = true)
#  |-- SUSP_RACE: string (nullable = true)
#  |-- SUSP_SEX: string (nullable = true)
#  |-- TRANSIT_DISTRICT: integer (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Lat_Lon: string (nullable = true)
#  |-- PATROL_BORO: string (nullable = true)
#  |-- STATION_NAME: string (nullable = true)
#  |-- VIC_AGE_GROUP: string (nullable = true)
#  |-- VIC_RACE: string (nullable = true)
#  |-- VIC_SEX: string (nullable = true)
# Number of rows:  1958512
# Number of columns:  35
# 23/05/08 16:28:13 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +----------+------------+-------------------+------------+------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+--------+----------+-----------+----------+----------+--------------+---------+--------+----------------+-----------------+------------------+--------------------+--------------------+------------+-------------+--------------+-------+
# |CMPLNT_NUM|CMPLNT_FR_DT|       CMPLNT_FR_TM|CMPLNT_TO_DT|CMPLNT_TO_TM|ADDR_PCT_CD|    RPT_DT|KY_CD|           OFNS_DESC|PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD| LAW_CAT_CD|  BORO_NM|LOC_OF_OCCUR_DESC|PREM_TYP_DESC|      JURIS_DESC|JURISDICTION_CODE|PARKS_NM|HADEVELOPT|HOUSING_PSA|X_COORD_CD|Y_COORD_CD|SUSP_AGE_GROUP|SUSP_RACE|SUSP_SEX|TRANSIT_DISTRICT|         Latitude|         Longitude|             Lat_Lon|         PATROL_BORO|STATION_NAME|VIC_AGE_GROUP|      VIC_RACE|VIC_SEX|
# +----------+------------+-------------------+------------+------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+--------+----------+-----------+----------+----------+--------------+---------+--------+----------------+-----------------+------------------+--------------------+--------------------+------------+-------------+--------------+-------+
# | 211921838|  08/31/2019|2023-05-08 18:00:00|        null|        null|         71|09/05/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR| BROOKLYN|             null|       STREET|N.Y. POLICE DEPT|                0|    null|      null|       null|   1001797|    182700|          null|     null|    null|            null|40.66813685500005|-73.93674924299995|(40.6681368550000...|PATROL BORO BKLYN...|        null|        45-64|         BLACK|      F|
# | 751236093|  06/19/2013|2023-05-08 16:30:00|        null|        null|         40|06/19/2013|  118|   DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|     FELONY|    BRONX|             null|       STREET|N.Y. POLICE DEPT|                0|      NA|      null|         NA|   1004972|    234409|          null|     null|    null|            null|      40.81005831|     -73.925144953|(40.81005831, -73...|   PATROL BORO BRONX|        null|         null|       UNKNOWN|      E|
# | 212455683|  08/27/2019|2023-05-08 06:00:00|  08/28/2019|    06:30:00|         45|08/28/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR|    BRONX|          REAR OF|       STREET|N.Y. POLICE DEPT|                0|    null|      null|       null|   1027350|    245455|          null|     null|    null|            null|40.84029557200005|-73.84423546299998|(40.8402955720000...|   PATROL BORO BRONX|        null|        25-44|WHITE HISPANIC|      F|
# | 635334663|  08/28/2019|2023-05-08 15:00:00|  08/29/2019|    00:05:00|        101|08/29/2019|  110|GRAND LARCENY OF ...|  441|LARCENY,GRAND OF ...|       COMPLETED|     FELONY|   QUEENS|             null|       STREET|N.Y. POLICE DEPT|                0|    null|      null|       null|   1052985|    157694|       UNKNOWN|  UNKNOWN|       U|            null|40.59925153100005|-73.75248562599995|(40.5992515310000...|PATROL BORO QUEEN...|        null|      UNKNOWN|       UNKNOWN|      D|
# | 812789888|  06/02/2015|2023-05-08 22:20:00|        null|        null|         13|06/02/2015|  109|       GRAND LARCENY|  443|LARCENY,GRAND OF ...|       COMPLETED|     FELONY|MANHATTAN|             null|       STREET|N.Y. POLICE DEPT|                0|    null|      null|         NA|    989164|    207429|          null|     null|    null|            null|     40.736028194|     -73.982269757|(40.736028194, -7...|PATROL BORO MAN S...|        null|         null|       UNKNOWN|      D|
# +----------+------------+-------------------+------------+------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+--------+----------+-----------+----------+----------+--------------+---------+--------+----------------+-----------------+------------------+--------------------+--------------------+------------+-------------+--------------+-------+
# only showing top 5 rows
# [Stage 8:>                                                          (0 + 1) / 1]
# +-------+-------------------+------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+
# |summary|         CMPLNT_NUM|CMPLNT_FR_DT|CMPLNT_TO_DT|CMPLNT_TO_TM|       ADDR_PCT_CD|    RPT_DT|             KY_CD|           OFNS_DESC|             PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD|LAW_CAT_CD|      BORO_NM|LOC_OF_OCCUR_DESC|     PREM_TYP_DESC|      JURIS_DESC| JURISDICTION_CODE|            PARKS_NM|          HADEVELOPT|       HOUSING_PSA|        X_COORD_CD|        Y_COORD_CD|    SUSP_AGE_GROUP|           SUSP_RACE|SUSP_SEX| TRANSIT_DISTRICT|           Latitude|          Longitude|             Lat_Lon|         PATROL_BORO|  STATION_NAME|    VIC_AGE_GROUP|            VIC_RACE|VIC_SEX|
# +-------+-------------------+------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+
# |  count|            1958512|     1958347|     1522902|     1524069|           1957951|   1958512|           1958512|             1953781|           1956813|             1956813|         1958473|   1958512|      1955411|          1553789|           1947974|         1958512|           1956813|             1038089|               87436|           1542869|           1954032|           1954032|            736026|             1078864| 1045572|            42960|            1954032|            1954032|             1954032|             1956700|         42960|          1548465|             1958431|1958447|
# |   mean|5.500681734125775E8|        null|        null|        null|63.348162441245975|      null| 296.8777985531873|                null| 412.7305041411724|                null|            null|      null|         null|             null|              null|            null|0.7139997536811131|                null|                null| 6245.155305023682|1004882.5818916988| 207111.1648939219|             464.1|                null|    null|13.53554469273743| 40.735105939272586| -73.92552104371444|                null|                null|          null|228.7927927927928|                null|   null|
# | stddev|2.596912175119076E8|        null|        null|        null| 34.50520432939566|      null|151.09440654529442|                null|217.57955918094126|                null|            null|      null|         null|             null|              null|            null| 6.680951294059437|                null|                null|13367.500163763392|21686.109229857488|30788.415922019147|1172.6431928029594|                null|    null|12.45881571596203|0.08449444940879369|0.07820813294561418|                null|                null|          null|777.2086430661171|                null|   null|
# |    min|          100000065|  01/01/1955|  01/01/1981|    00:00:00|                 1|01/01/2006|               101| ADMINISTRATIVE CODE|               100|A.B.C.,FALSE PROO...|       ATTEMPTED|    FELONY|        BRONX|         FRONT OF|ABANDONED BUILDING|         AMTRACK|                 0|"""UNCLE"" VITO E...|1162-1176 WASHING...|             1,193|            152021|            121131|                -1|AMERICAN INDIAN/A...|       F|                1|       40.498905363|      -76.995012742|(40.498905363, -7...|PATROL BORO BKLYN...|"AVENUE ""H"""|               -1|AMERICAN INDIAN/A...|      D|
# |    max|          999999664|  12/31/2021|  12/31/2021|    24:00:00|               123|12/31/2021|               881|VEHICLE AND TRAFF...|               969| WOUNDS,REPORTING OF|       COMPLETED| VIOLATION|STATEN ISLAND|          REAR OF|       VIDEO STORE|U.S. PARK POLICE|                97|       ZION TRIANGLE|     WYCKOFF GARDENS|                NA|           1067298|           5205015|           UNKNOWN|      WHITE HISPANIC|       U|               34|       54.304231906|      -73.700315857|(54.304231906, -7...|PATROL BORO STATE...| ZEREGA AVENUE|          UNKNOWN|      WHITE HISPANIC|      U|
# +-------+-------------------+------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+

# %%
from pyspark.sql.functions import col

# Generate column-level statistics using Spark DataFrame API
col_stats = df.select([col(c).cast("string") for c in df.columns]).describe()

# Display column-level statistics
col_stats.show()

# Generate row-level statistics using Spark DataFrame API
row_stats = df.summary()

row_stats.show()
# Out:
# 23/05/09 01:11:01 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#
# |    max|          999999664|  12/31/2021|2023-05-09 23:59:00|  12/31/2021|    24:00:00|                94|12/31/2021|               881|VEHICLE AND TRAFF...|               969| WOUNDS,REPORTING OF|       COMPLETED| VIOLATION|STATEN ISLAND|          REAR OF|       VIDEO STORE|U.S. PARK POLICE|                97|       ZION TRIANGLE|     WYCKOFF GARDENS|                NA|            999999|           5205015|           UNKNOWN|      WHITE HISPANIC|       U|                4|       54.304231906|      -76.995012742|(54.304231906, -7...|PATROL BORO STATE...| ZEREGA AVENUE|          UNKNOWN|      WHITE HISPANIC|      U|
# +-------+-------------------+------------+-------------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+
# +-------+-------------------+------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+
# |summary|         CMPLNT_NUM|CMPLNT_FR_DT|CMPLNT_TO_DT|CMPLNT_TO_TM|       ADDR_PCT_CD|    RPT_DT|             KY_CD|           OFNS_DESC|             PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD|LAW_CAT_CD|      BORO_NM|LOC_OF_OCCUR_DESC|     PREM_TYP_DESC|      JURIS_DESC| JURISDICTION_CODE|            PARKS_NM|          HADEVELOPT|       HOUSING_PSA|        X_COORD_CD|        Y_COORD_CD|    SUSP_AGE_GROUP|           SUSP_RACE|SUSP_SEX| TRANSIT_DISTRICT|           Latitude|          Longitude|             Lat_Lon|         PATROL_BORO|  STATION_NAME|    VIC_AGE_GROUP|            VIC_RACE|VIC_SEX|
# +-------+-------------------+------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+
# |  count|            1958512|     1958347|     1522902|     1524069|           1957951|   1958512|           1958512|             1953781|           1956813|             1956813|         1958473|   1958512|      1955411|          1553789|           1947974|         1958512|           1956813|             1038089|               87436|           1542869|           1954032|           1954032|            736026|             1078864| 1045572|            42960|            1954032|            1954032|             1954032|             1956700|         42960|          1548465|             1958431|1958447|
# |   mean|5.500681734125775E8|        null|        null|        null|63.348162441245975|      null| 296.8777985531873|                null| 412.7305041411724|                null|            null|      null|         null|             null|              null|            null|0.7139997536811131|                null|                null| 6245.155305023682|1004882.5818916988| 207111.1648939219|             464.1|                null|    null|13.53554469273743| 40.735105939272586| -73.92552104371444|                null|                null|          null|228.7927927927928|                null|   null|
# | stddev|2.596912175119076E8|        null|        null|        null| 34.50520432939566|      null|151.09440654529442|                null|217.57955918094126|                null|            null|      null|         null|             null|              null|            null| 6.680951294059437|                null|                null|13367.500163763392|21686.109229857488|30788.415922019147|1172.6431928029594|                null|    null|12.45881571596203|0.08449444940879369|0.07820813294561418|                null|                null|          null|777.2086430661171|                null|   null|
# |    min|          100000065|  01/01/1955|  01/01/1981|    00:00:00|                 1|01/01/2006|               101| ADMINISTRATIVE CODE|               100|A.B.C.,FALSE PROO...|       ATTEMPTED|    FELONY|        BRONX|         FRONT OF|ABANDONED BUILDING|         AMTRACK|                 0|"""UNCLE"" VITO E...|1162-1176 WASHING...|             1,193|            152021|            121131|                -1|AMERICAN INDIAN/A...|       F|                1|       40.498905363|      -76.995012742|(40.498905363, -7...|PATROL BORO BKLYN...|"AVENUE ""H"""|               -1|AMERICAN INDIAN/A...|      D|
# |    25%|          325243600|        null|        null|        null|                40|      null|               117|                null|               254|                null|            null|      null|         null|             null|              null|            null|                 0|                null|                null|             477.0|            991788|            184415|            -965.0|                null|    null|                3|       40.672786795|      -73.972819638|                null|                null|          null|            -85.0|                null|   null|
# |    50%|          550077760|        null|        null|        null|                63|      null|               341|                null|               380|                null|            null|      null|         null|             null|              null|            null|                 0|                null|                null|             696.0|           1004396|            206077|             928.0|                null|    null|               11| 40.732262379000076|      -73.927269471|                null|                null|          null|            507.0|                null|   null|
# |    75%|          774715147|        null|        null|        null|                94|      null|               351|                null|               637|                null|            null|      null|         null|             null|              null|            null|                 0|                null|                null|            1193.0|           1016702|            235143|            1018.0|                null|    null|               30|        40.81206043|      -73.882829229|                null|                null|          null|            938.0|                null|   null|
# |    max|          999999664|  12/31/2021|  12/31/2021|    24:00:00|               123|12/31/2021|               881|VEHICLE AND TRAFF...|               969| WOUNDS,REPORTING OF|       COMPLETED| VIOLATION|STATEN ISLAND|          REAR OF|       VIDEO STORE|U.S. PARK POLICE|                97|       ZION TRIANGLE|     WYCKOFF GARDENS|                NA|           1067298|           5205015|           UNKNOWN|      WHITE HISPANIC|       U|               34|       54.304231906|      -73.700315857|(54.304231906, -7...|PATROL BORO STATE...| ZEREGA AVENUE|          UNKNOWN|      WHITE HISPANIC|      U|
# +-------+-------------------+------------+------------+------------+------------------+----------+------------------+--------------------+------------------+--------------------+----------------+----------+-------------+-----------------+------------------+----------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+--------------------+--------+-----------------+-------------------+-------------------+--------------------+--------------------+--------------+-----------------+--------------------+-------+

# %% [markdown]
# ## Cleaning, Validation

# %%
# check each col for percent missing value
from pyspark.sql.functions import count, when, col

# Convert the timestamp column to double
df = df.withColumn("CMPLNT_FR_TM_double", df["CMPLNT_FR_TM"].cast("double"))

# Calculate the count of missing values for each column
missing_values_count = df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns])

# Calculate the percentage of missing values for each column
missing_values_percent = missing_values_count.select([(col(c) / df.count() * 100).alias(c + '_percent') for c in df.columns])

missing_values_percent.show()
# Out:
# [Stage 116:=================================================>     (17 + 2) / 19]
# +------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+-------------------+------------------+------------------+------------------------+------------------+-------------------+-------------------------+---------------------+------------------+-------------------------+-----------------+------------------+-------------------+-------------------+-------------------+----------------------+-----------------+-----------------+------------------------+-------------------+-------------------+-------------------+-------------------+--------------------+---------------------+--------------------+--------------------+---------------------------+
# |CMPLNT_NUM_percent|CMPLNT_FR_DT_percent|CMPLNT_FR_TM_percent|CMPLNT_TO_DT_percent|CMPLNT_TO_TM_percent| ADDR_PCT_CD_percent|RPT_DT_percent|KY_CD_percent|  OFNS_DESC_percent|     PD_CD_percent|   PD_DESC_percent|CRM_ATPT_CPTD_CD_percent|LAW_CAT_CD_percent|    BORO_NM_percent|LOC_OF_OCCUR_DESC_percent|PREM_TYP_DESC_percent|JURIS_DESC_percent|JURISDICTION_CODE_percent| PARKS_NM_percent|HADEVELOPT_percent|HOUSING_PSA_percent| X_COORD_CD_percent| Y_COORD_CD_percent|SUSP_AGE_GROUP_percent|SUSP_RACE_percent| SUSP_SEX_percent|TRANSIT_DISTRICT_percent|   Latitude_percent|  Longitude_percent|    Lat_Lon_percent|PATROL_BORO_percent|STATION_NAME_percent|VIC_AGE_GROUP_percent|    VIC_RACE_percent|     VIC_SEX_percent|CMPLNT_FR_TM_double_percent|
# +------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+-------------------+------------------+------------------+------------------------+------------------+-------------------+-------------------------+---------------------+------------------+-------------------------+-----------------+------------------+-------------------+-------------------+-------------------+----------------------+-----------------+-----------------+------------------------+-------------------+-------------------+-------------------+-------------------+--------------------+---------------------+--------------------+--------------------+---------------------------+
# |               0.0|0.008424763289681145| 5.61650885978743E-4|   22.24188567647275|  22.182299623387554|0.028644195184915896|           0.0|          0.0|0.24156094014231214|0.0867495322979895|0.0867495322979895|    0.001991307686651907|               0.0|0.15833449067455294|        20.66482104781589|   0.5380615487676359|               0.0|       0.0867495322979895|46.99603576592842| 95.53559028486933| 21.222387200078426|0.22874508810770627|0.22874508810770627|     62.41912227241906|44.91409804994812|46.61395998594852|       97.80649799439574|0.22874508810770627|0.22874508810770627|0.22874508810770627|0.09251921867213476|   97.80649799439574|   20.936660076629604|0.004135792887661...|0.003318846144419...|        5.61650885978743E-4|
# +------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+-------------------+------------------+------------------+------------------------+------------------+-------------------+-------------------------+---------------------+------------------+-------------------------+-----------------+------------------+-------------------+-------------------+-------------------+----------------------+-----------------+-----------------+------------------------+-------------------+-------------------+-------------------+-------------------+--------------------+---------------------+--------------------+--------------------+---------------------------+

# %%
# dropping rows with null values in selected columns
df = df.na.drop(subset=['Y_COORD_CD', 'X_COORD_CD', 'Latitude', 'Longitude', 'CRM_ATPT_CPTD_CD', 'CMPLNT_FR_TM', 'Lat_Lon', 'CMPLNT_FR_DT', 'BORO_NM', 'OFNS_DESC'])

# %%
# dropping columns that are not significant for future data exploration
df = df.drop('PARKS_NM', 'STATION_NAME', 'TRANSIT_DISTRICT', 'HADEVELOPT', 'HOUSING_PSA', 'CMPLNT_TO_DT', 'CMPLNT_TO_TM')

# %%
# replacing null values in 'LOC_OF_OCCUR_DESC' with 'UNKNOWN'
df = df.fillna({'LOC_OF_OCCUR_DESC':'UNKNOWN'})

# %%
# replacing null values in 'VIC_RACE' with 'UNKNOWN'
df = df.fillna({'VIC_RACE':'UNKNOWN'})

# %%
# replacing null values in 'VIC_AGE_GROUP' with 'UNKNOWN'
df = df.fillna({'VIC_AGE_GROUP':'UNKNOWN'})

# %%
# replacing null values in 'VIC_SEX' with 'UNKNOWN'
df = df.fillna({'VIC_SEX':'UNKNOWN'})

# %%
print('Clean dataset: ')
print("Observations: ", df.count())
print("Variables: ", len(df.columns))
df.show(5)
# Out:
# Clean dataset:
# Observations:  1946157
# Variables:  29
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+-----------------+------------------+--------------------+--------------------+-------------+--------------+-------+-------------------+
# |CMPLNT_NUM|CMPLNT_FR_DT|       CMPLNT_FR_TM|ADDR_PCT_CD|    RPT_DT|KY_CD|           OFNS_DESC|PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD| LAW_CAT_CD|  BORO_NM|LOC_OF_OCCUR_DESC|PREM_TYP_DESC|      JURIS_DESC|JURISDICTION_CODE|X_COORD_CD|Y_COORD_CD|SUSP_AGE_GROUP|SUSP_RACE|SUSP_SEX|         Latitude|         Longitude|             Lat_Lon|         PATROL_BORO|VIC_AGE_GROUP|      VIC_RACE|VIC_SEX|CMPLNT_FR_TM_double|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+-----------------+------------------+--------------------+--------------------+-------------+--------------+-------+-------------------+
# | 211921838|  08/31/2019|2023-05-09 18:00:00|         71|09/05/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR| BROOKLYN|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1001797|    182700|          null|     null|    null|40.66813685500005|-73.93674924299995|(40.6681368550000...|PATROL BORO BKLYN...|        45-64|         BLACK|      F|        1.6836696E9|
# | 751236093|  06/19/2013|2023-05-09 16:30:00|         40|06/19/2013|  118|   DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|     FELONY|    BRONX|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1004972|    234409|          null|     null|    null|      40.81005831|     -73.925144953|(40.81005831, -73...|   PATROL BORO BRONX|      UNKNOWN|       UNKNOWN|      E|        1.6836642E9|
# | 212455683|  08/27/2019|2023-05-09 06:00:00|         45|08/28/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR|    BRONX|          REAR OF|       STREET|N.Y. POLICE DEPT|                0|   1027350|    245455|          null|     null|    null|40.84029557200005|-73.84423546299998|(40.8402955720000...|   PATROL BORO BRONX|        25-44|WHITE HISPANIC|      F|        1.6836264E9|
# | 635334663|  08/28/2019|2023-05-09 15:00:00|        101|08/29/2019|  110|GRAND LARCENY OF ...|  441|LARCENY,GRAND OF ...|       COMPLETED|     FELONY|   QUEENS|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1052985|    157694|       UNKNOWN|  UNKNOWN|       U|40.59925153100005|-73.75248562599995|(40.5992515310000...|PATROL BORO QUEEN...|      UNKNOWN|       UNKNOWN|      D|        1.6836588E9|
# | 812789888|  06/02/2015|2023-05-09 22:20:00|         13|06/02/2015|  109|       GRAND LARCENY|  443|LARCENY,GRAND OF ...|       COMPLETED|     FELONY|MANHATTAN|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|    989164|    207429|          null|     null|    null|     40.736028194|     -73.982269757|(40.736028194, -7...|PATROL BORO MAN S...|      UNKNOWN|       UNKNOWN|      D|        1.6836852E9|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+-----------------+------------------+--------------------+--------------------+-------------+--------------+-------+-------------------+
# only showing top 5 rows

# %%
df = df.fillna('UNKNOWN')

# %%
from pyspark.sql.types import StringType

for column in df.columns:
    if isinstance(df.schema[column].dataType, StringType):
        df.groupBy(column).count().orderBy(col('count').desc()).show(10)
        print('\n------------------------------------------\n')
# Out:
# +------------+-----+
# |CMPLNT_FR_DT|count|
# +------------+-----+
# |  01/01/2010|  633|
# |  01/01/2016|  599|
# |  01/01/2011|  597|
# |  01/01/2014|  596|
# |  01/01/2008|  582|
# |  01/01/2007|  574|
# |  01/01/2017|  554|
# |  01/01/2019|  542|
# |  01/01/2012|  532|
# |  01/01/2013|  522|
# +------------+-----+
# only showing top 10 rows
#
#
# ------------------------------------------
# +----------+-----+
# |    RPT_DT|count|
# +----------+-----+
# |11/01/2006|  489|
# |05/29/2007|  487|
# |06/05/2007|  483|
# |06/06/2007|  468|
# |09/17/2009|  465|
# |06/21/2006|  458|
# |08/16/2006|  458|
# |07/23/2008|  456|
# |10/04/2006|  456|
# |10/23/2007|  456|
# +----------+-----+
# only showing top 10 rows
#
#
# ------------------------------------------
# +--------------------+------+
# |           OFNS_DESC| count|
# +--------------------+------+
# |       PETIT LARCENY|332434|
# |       HARRASSMENT 2|254535|
# |ASSAULT 3 & RELAT...|204862|
# |CRIMINAL MISCHIEF...|197422|
# |       GRAND LARCENY|169426|
# |     DANGEROUS DRUGS|108730|
# |OFF. AGNST PUB OR...| 99817|
# |      FELONY ASSAULT| 77043|
# |             ROBBERY| 70369|
# |            BURGLARY| 66432|
# +--------------------+------+
# only showing top 10 rows
#
#
# ------------------------------------------
# +--------------------+------+
# |             PD_DESC| count|
# +--------------------+------+
# |           ASSAULT 3|168513|
# |HARASSMENT,SUBD 3...|166889|
# |LARCENY,PETIT FRO...|100945|
# |AGGRAVATED HARASS...| 97233|
# |HARASSMENT,SUBD 1...| 87646|
# |LARCENY,PETIT FRO...| 76504|
# |MISCHIEF, CRIMINA...| 67412|
# |ASSAULT 2,1,UNCLA...| 62186|
# |LARCENY,PETIT FRO...| 61673|
# |CRIMINAL MISCHIEF...| 55329|
# +--------------------+------+
# only showing top 10 rows
#
#
# ------------------------------------------
# +----------------+-------+
# |CRM_ATPT_CPTD_CD|  count|
# +----------------+-------+
# |       COMPLETED|1913348|
# |       ATTEMPTED|  32809|
# +----------------+-------+
#
#
# ------------------------------------------
# +-----------+-------+
# | LAW_CAT_CD|  count|
# +-----------+-------+
# |MISDEMEANOR|1085115|
# |     FELONY| 602685|
# |  VIOLATION| 258357|
# +-----------+-------+
#
#
# ------------------------------------------
# +-------------+------+
# |      BORO_NM| count|
# +-------------+------+
# |     BROOKLYN|576906|
# |    MANHATTAN|468624|
# |        BRONX|421387|
# |       QUEENS|389186|
# |STATEN ISLAND| 90054|
# +-------------+------+
#
#
# ------------------------------------------
# +-----------------+------+
# |LOC_OF_OCCUR_DESC| count|
# +-----------------+------+
# |           INSIDE|991686|
# |         FRONT OF|460092|
# |          UNKNOWN|401589|
# |      OPPOSITE OF| 51385|
# |          REAR OF| 41405|
# +-----------------+------+
#
#
# ------------------------------------------
# +--------------------+------+
# |       PREM_TYP_DESC| count|
# +--------------------+------+
# |              STREET|618448|
# |RESIDENCE - APT. ...|415849|
# |     RESIDENCE-HOUSE|192231|
# |RESIDENCE - PUBLI...|146468|
# |               OTHER| 51261|
# | COMMERCIAL BUILDING| 49877|
# |         CHAIN STORE| 47096|
# |TRANSIT - NYC SUBWAY| 41456|
# |    DEPARTMENT STORE| 39137|
# |      GROCERY/BODEGA| 25036|
# +--------------------+------+
# only showing top 10 rows
#
#
# ------------------------------------------
# +-------------------+-------+
# |         JURIS_DESC|  count|
# +-------------------+-------+
# |   N.Y. POLICE DEPT|1731450|
# |N.Y. HOUSING POLICE| 148450|
# |N.Y. TRANSIT POLICE|  42276|
# |     PORT AUTHORITY|   8836|
# |              OTHER|   6297|
# |DEPT OF CORRECTIONS|   2456|
# |    POLICE DEPT NYC|   2187|
# |TRI-BORO BRDG TUNNL|   1462|
# | HEALTH & HOSP CORP|    981|
# |  N.Y. STATE POLICE|    484|
# +-------------------+-------+
# only showing top 10 rows
#
#
# ------------------------------------------
# +--------------+-------+
# |SUSP_AGE_GROUP|  count|
# +--------------+-------+
# |       UNKNOWN|1424328|
# |         25-44| 280922|
# |         18-24| 103657|
# |         45-64|  99579|
# |           <18|  28971|
# |           65+|   8642|
# |          1017|      3|
# |          2020|      3|
# |          2018|      3|
# |          -960|      2|
# +--------------+-------+
# only showing top 10 rows
#
#
# ------------------------------------------
# +--------------------+-------+
# |           SUSP_RACE|  count|
# +--------------------+-------+
# |             UNKNOWN|1158056|
# |               BLACK| 399497|
# |      WHITE HISPANIC| 180055|
# |               WHITE| 115619|
# |      BLACK HISPANIC|  55190|
# |ASIAN / PACIFIC I...|  34572|
# |AMERICAN INDIAN/A...|   3166|
# |               OTHER|      2|
# +--------------------+-------+
#
#
# ------------------------------------------
# +--------+------+
# |SUSP_SEX| count|
# +--------+------+
# | UNKNOWN|905323|
# |       M|648527|
# |       F|202481|
# |       U|189826|
# +--------+------+
#
#
# ------------------------------------------
# +--------------------+-----+
# |             Lat_Lon|count|
# +--------------------+-----+
# |(40.750430768, -7...| 5204|
# |(40.679700408, -7...| 3864|
# |(40.791151867, -7...| 2141|
# |(40.837323511, -7...| 1757|
# |(40.710093847, -7...| 1637|
# |(40.869058532, -7...| 1617|
# |(40.733926841, -7...| 1614|
# |(40.804384046, -7...| 1407|
# |(40.756266207, -7...| 1405|
# |(40.651700904, -7...| 1404|
# +--------------------+-----+
# only showing top 10 rows
#
#
# ------------------------------------------
# +--------------------+------+
# |         PATROL_BORO| count|
# +--------------------+------+
# |   PATROL BORO BRONX|421336|
# |PATROL BORO BKLYN...|289722|
# |PATROL BORO BKLYN...|287208|
# |PATROL BORO MAN S...|235151|
# |PATROL BORO MAN N...|232944|
# |PATROL BORO QUEEN...|201867|
# |PATROL BORO QUEEN...|187878|
# |PATROL BORO STATE...| 90029|
# |             UNKNOWN|    22|
# +--------------------+------+
#
#
# ------------------------------------------
# +-------------+------+
# |VIC_AGE_GROUP| count|
# +-------------+------+
# |        25-44|646609|
# |      UNKNOWN|606716|
# |        45-64|338375|
# |        18-24|196155|
# |          <18| 88090|
# |          65+| 70101|
# |          929|     4|
# |         -943|     3|
# |          946|     3|
# |          943|     3|
# +-------------+------+
# only showing top 10 rows
#
#
# ------------------------------------------
# +--------------------+------+
# |            VIC_RACE| count|
# +--------------------+------+
# |             UNKNOWN|636190|
# |               BLACK|470018|
# |               WHITE|332923|
# |      WHITE HISPANIC|316066|
# |ASIAN / PACIFIC I...|115400|
# |      BLACK HISPANIC| 66872|
# |AMERICAN INDIAN/A...|  8680|
# |               OTHER|     8|
# +--------------------+------+
#
#
# ------------------------------------------
# [Stage 174:=================================================>     (17 + 2) / 19]
# +-------+------+
# |VIC_SEX| count|
# +-------+------+
# |      F|763836|
# |      M|644400|
# |      E|294017|
# |      D|243843|
# |UNKNOWN|    61|
# +-------+------+
#
#
# ------------------------------------------

# %%
from pyspark.sql.functions import when, col

# modify abbreviations in VIC_SEX and SUSP_SEX columns
df = df.withColumn('VIC_SEX', when(col('VIC_SEX') == 'U', 'UNKNOWN')
                          .when(col('VIC_SEX') == 'E', 'UNKNOWN')
                          .when(col('VIC_SEX') == 'D', 'BUSINESS/ORGANIZATION')
                          .when(col('VIC_SEX') == 'F', 'FEMALE')
                          .when(col('VIC_SEX') == 'M', 'MALE')
                          .otherwise(col('VIC_SEX')))
df = df.withColumn('SUSP_SEX', when(col('SUSP_SEX') == 'U', 'UNKNOWN')
                            .when(col('SUSP_SEX') == 'E', 'UNKNOWN')
                            .when(col('SUSP_SEX') == 'D', 'BUSINESS/ORGANIZATION')
                            .when(col('SUSP_SEX') == 'F', 'FEMALE')
                            .when(col('SUSP_SEX') == 'M', 'MALE')
                            .otherwise(col('SUSP_SEX')))

# remove incorrect age groups
age_categories = ['<18', '18-24', '25-44', '45-64', '65+', 'UNKNOWN']
df = df.filter(col('VIC_AGE_GROUP').isin(age_categories) & col('SUSP_AGE_GROUP').isin(age_categories))

# %%
df.show(10)
# Out:
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+
# |CMPLNT_NUM|CMPLNT_FR_DT|       CMPLNT_FR_TM|ADDR_PCT_CD|    RPT_DT|KY_CD|           OFNS_DESC|PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD| LAW_CAT_CD|  BORO_NM|LOC_OF_OCCUR_DESC|PREM_TYP_DESC|      JURIS_DESC|JURISDICTION_CODE|X_COORD_CD|Y_COORD_CD|SUSP_AGE_GROUP|SUSP_RACE|SUSP_SEX|          Latitude|         Longitude|             Lat_Lon|         PATROL_BORO|VIC_AGE_GROUP|      VIC_RACE|             VIC_SEX|CMPLNT_FR_TM_double|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+
# | 211921838|  08/31/2019|2023-05-09 18:00:00|         71|09/05/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR| BROOKLYN|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1001797|    182700|       UNKNOWN|  UNKNOWN| UNKNOWN| 40.66813685500005|-73.93674924299995|(40.6681368550000...|PATROL BORO BKLYN...|        45-64|         BLACK|              FEMALE|        1.6836696E9|
# | 751236093|  06/19/2013|2023-05-09 16:30:00|         40|06/19/2013|  118|   DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|     FELONY|    BRONX|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|       40.81005831|     -73.925144953|(40.81005831, -73...|   PATROL BORO BRONX|      UNKNOWN|       UNKNOWN|             UNKNOWN|        1.6836642E9|
# | 212455683|  08/27/2019|2023-05-09 06:00:00|         45|08/28/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR|    BRONX|          REAR OF|       STREET|N.Y. POLICE DEPT|                0|   1027350|    245455|       UNKNOWN|  UNKNOWN| UNKNOWN| 40.84029557200005|-73.84423546299998|(40.8402955720000...|   PATROL BORO BRONX|        25-44|WHITE HISPANIC|              FEMALE|        1.6836264E9|
# | 635334663|  08/28/2019|2023-05-09 15:00:00|        101|08/29/2019|  110|GRAND LARCENY OF ...|  441|LARCENY,GRAND OF ...|       COMPLETED|     FELONY|   QUEENS|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1052985|    157694|       UNKNOWN|  UNKNOWN| UNKNOWN| 40.59925153100005|-73.75248562599995|(40.5992515310000...|PATROL BORO QUEEN...|      UNKNOWN|       UNKNOWN|BUSINESS/ORGANIZA...|        1.6836588E9|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+
# only showing top 10 rows

# %%
df.count()
# Out:
# 1945988

# %%
from pyspark.sql.functions import when, col

# Fill in missing values in the OFNS_DESC column with "OTHER"
df = df.withColumn('OFNS_DESC', when(col('OFNS_DESC').isNull(), 'OTHER')
                                .otherwise(col('OFNS_DESC')))

# %%
from pyspark.sql.functions import count

df.groupBy('OFNS_DESC').agg(count('*').alias('count')).show()
# Out:
# [Stage 181:=================================================>     (17 + 2) / 19]
# +--------------------+------+
# |           OFNS_DESC| count|
# +--------------------+------+
# |OTHER TRAFFIC INF...|     4|
# |ANTICIPATORY OFFE...|    34|
# |   FELONY SEX CRIMES|     8|
# |OTHER OFFENSES RE...|  4234|
# |VEHICLE AND TRAFF...| 24955|
# |KIDNAPPING & RELA...|   760|
# |OFF. AGNST PUB OR...| 99801|
# |PETIT LARCENY OF ...|   370|
# |      FELONY ASSAULT| 77033|
# |OFFENSES RELATED ...|   425|
# |ALCOHOLIC BEVERAG...|   359|
# |CRIMINAL MISCHIEF...|197409|
# |         THEFT-FRAUD| 20064|
# |   THEFT OF SERVICES|  1220|
# |            JOSTLING|   109|
# |MISCELLANEOUS PEN...| 49907|
# |LOITERING/GAMBLIN...|    60|
# |               ARSON|  4561|
# |OFFENSES AGAINST ...|  4940|
# |            GAMBLING|   797|
# +--------------------+------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import when

# categorize property related offenses
prop = ['BURGLARY', 'PETIT LARCENY', 'GRAND LARCENY', 'ROBBERY', 'THEFT-FRAUD', 
        'GRAND LARCENY OF MOTOR VEHICLE', 'FORGERY', 'JOSTLING', 'ARSON',
        'PETIT LARCENY OF MOTOR VEHICLE', 'OTHER OFFENSES RELATED TO THEF',
        "BURGLAR'S TOOLS", 'FRAUDS', 'POSSESSION OF STOLEN PROPERTY',
        'CRIMINAL MISCHIEF & RELATED OF', 'OFFENSES INVOLVING FRAUD',
        'FRAUDULENT ACCOSTING', 'THEFT OF SERVICES']

# categorize sexual offenses
sexual = ['SEX CRIMES', 'HARRASSMENT 2', 'RAPE', 'PROSTITUTION & RELATED OFFENSES',
          'FELONY SEX CRIMES', 'LOITERING/DEVIATE SEX']

# categorize drugs/alcohol related offenses
drug_alch = ['DANGEROUS DRUGS', 'INTOXICATED & IMPAIRED DRIVING',
             'ALCOHOLIC BEVERAGE CONTROL LAW', 'INTOXICATED/IMPAIRED DRIVING',
             'UNDER THE INFLUENCE OF DRUGS', 'LOITERING FOR DRUG PURPOSES']

# categorize personal (assault/homicidal/kidnapping/weapon) offenses
personal = ['ASSAULT 3 & RELATED OFFENSES', 'FELONY ASSAULT',
            'OFFENSES AGAINST THE PERSON', 'HOMICIDE-NEGLIGENT,UNCLASSIFIE',
            'HOMICIDE-NEGLIGENT-VEHICLE', 'KIDNAPPING & RELATED OFFENSES',
            'ENDAN WELFARE INCOMP', 'OFFENSES RELATED TO CHILDREN',
            'CHILD ABANDONMENT/NON SUPPORT', 'KIDNAPPING', 'DANGEROUS WEAPONS',
            'UNLAWFUL POSS. WEAP. ON SCHOOL']

# categorize administrative/trespassing/loitering/traffic offenses
admin = ['OFF. AGNST PUB ORD SENSBLTY &', 'CRIMINAL TRESPASS', 
         'VEHICLE AND TRAFFIC LAWS', 'OFFENSES AGAINST PUBLIC ADMINI',
         'ADMINISTRATIVE CODE', 'OFFENSES AGAINST PUBLIC SAFETY',
         'LOITERING/GAMBLING (CARDS, DIC', 'DISORDERLY CONDUCT',
         'NEW YORK CITY HEALTH CODE', 'DISRUPTION OF A RELIGIOUS SERV',
         'LOITERING', 'ADMINISTRATIVE CODES']

# categorize remaining offenses as other
other = ['MISCELLANEOUS PENAL LAW', 'OFFENSES AGAINST MARRIAGE UNCL',
         'OTHER STATE LAWS (NON PENAL LAW)', 'FORTUNE TELLING',
         'NYS LAWS-UNCLASSIFIED VIOLATION', 'LOITERING/GAMBLING (CARDS, DIC',
         'GAMBLING', 'OTHER STATE LAWS (NON PENAL LA', 'OTHER STATE LAWS',
         'ANTICIPATORY OFFENSES', 'ESCAPE 3', 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED',
         'NYS LAWS-UNCLASSIFIED FELONY', 'UNAUTHORIZED USE OF A VEHICLE', 'OTHER']


# combine all under a new column
offenses = ['PROPERTY', 'SEXUAL', 'DRUGS/ALCOHOL', 'PERSONAL', 'ADMINISTRATIVE']

conditions = [(df['OFNS_DESC'].isin(prop)),
              (df['OFNS_DESC'].isin(sexual)),
              (df['OFNS_DESC'].isin(drug_alch)),
              (df['OFNS_DESC'].isin(personal)),
              (df['OFNS_DESC'].isin(admin))]

df = df.withColumn('OFNS_CATS', when(conditions[0], offenses[0])
                   .when(conditions[1], offenses[1])
                   .when(conditions[2], offenses[2])
                   .when(conditions[3], offenses[3])
                   .when(conditions[4], offenses[4])
                   .otherwise('OTHER'))

# %%
df.show(10)
# Out:
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+---------+
# |CMPLNT_NUM|CMPLNT_FR_DT|       CMPLNT_FR_TM|ADDR_PCT_CD|    RPT_DT|KY_CD|           OFNS_DESC|PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD| LAW_CAT_CD|  BORO_NM|LOC_OF_OCCUR_DESC|PREM_TYP_DESC|      JURIS_DESC|JURISDICTION_CODE|X_COORD_CD|Y_COORD_CD|SUSP_AGE_GROUP|SUSP_RACE|SUSP_SEX|          Latitude|         Longitude|             Lat_Lon|         PATROL_BORO|VIC_AGE_GROUP|      VIC_RACE|             VIC_SEX|CMPLNT_FR_TM_double|OFNS_CATS|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+---------+
# | 119265656|  01/17/2011|2023-05-09 22:15:00|         69|01/18/2011|  118|   DANGEROUS WEAPONS|  792|WEAPONS POSSESSIO...|       COMPLETED|     FELONY| BROOKLYN|          UNKNOWN|       STREET|N.Y. POLICE DEPT|                0|   1012807|    175576|       UNKNOWN|  UNKNOWN| UNKNOWN|      40.648554384|     -73.897091361|(40.648554384, -7...|PATROL BORO BKLYN...|        18-24|         BLACK|                MALE|        1.6836849E9| PERSONAL|
# | 443867628|  08/30/2019|2023-05-09 09:20:00|         60|08/30/2019|  106|      FELONY ASSAULT|  109|ASSAULT 2,1,UNCLA...|       COMPLETED|     FELONY| BROOKLYN|      OPPOSITE OF|        OTHER|N.Y. POLICE DEPT|                0|    993722|    153422|         25-44|    WHITE|    MALE|40.587787224000074|-73.96589851799997|(40.5877872240000...|PATROL BORO BKLYN...|          65+|         WHITE|              FEMALE|        1.6836384E9| PERSONAL|
# | 908879475|  08/22/2019|2023-05-09 19:35:00|         32|08/22/2019|  109|       GRAND LARCENY|  443|LARCENY,GRAND OF ...|       COMPLETED|     FELONY|MANHATTAN|         FRONT OF|        OTHER|N.Y. POLICE DEPT|                0|   1000811|    234122|       UNKNOWN|  UNKNOWN| UNKNOWN|40.809279354000076|     -73.940176921|(40.8092793540000...|PATROL BORO MAN N...|      UNKNOWN|       UNKNOWN|BUSINESS/ORGANIZA...|        1.6836753E9| PROPERTY|
# | 715678470|  08/19/2019|2023-05-09 21:00:00|        107|08/20/2019|  341|       PETIT LARCENY|  321|LARCENY,PETIT FRO...|       COMPLETED|MISDEMEANOR|   QUEENS|           INSIDE|       STREET|N.Y. POLICE DEPT|                0|   1041200|    206444|       UNKNOWN|  UNKNOWN| UNKNOWN| 40.73314263800006|-73.79451162099997|(40.7331426380000...|PATROL BORO QUEEN...|        45-64|         WHITE|                MALE|        1.6836804E9| PROPERTY|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+-------------+----------------+-----------------+----------+----------+--------------+---------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+---------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import col

# fix datatypes of categorical columns
categorical_columns = set(df.columns) - set(['CMPLNT_NUM', 'RPT_DT', 'Latitude', 'Longitude', 'CMPLNT_DT'])
for column in categorical_columns:
    df = df.withColumn(column, col(column).cast('string'))

# set the order of some categorical columns so the visualizations in EDA will be consistent
df = df.withColumn('LAW_CAT_CD', df['LAW_CAT_CD'].cast('string').cast('string')
                   .cast("string")).orderBy(df['LAW_CAT_CD'].cast("string").isin(['VIOLATION', 'MISDEMEANOR', 'FELONY']).desc())
df = df.withColumn('SUSP_SEX', df['SUSP_SEX'].cast('string').cast('string')
                   .cast("string")).orderBy(df['SUSP_SEX'].cast("string").isin(['FEMALE', 'MALE', 'UNKNOWN']).desc())
df = df.withColumn('VIC_SEX', df['VIC_SEX'].cast('string').cast('string')
                   .cast("string")).orderBy(df['VIC_SEX'].cast("string").isin(['FEMALE', 'MALE', 'BUSINESS/ORGANIZATION', 'UNKNOWN']).desc())
df = df.withColumn('VIC_AGE_GROUP', df['VIC_AGE_GROUP'].cast('string').cast('string')
                   .cast("string")).orderBy(df['VIC_AGE_GROUP'].cast("string").isin(['<18', '18-24', '25-44', '45-64', '65+', 'UNKNOWN']).desc())
df = df.withColumn('SUSP_AGE_GROUP', df['SUSP_AGE_GROUP'].cast('string').cast('string')
                   .cast("string")).orderBy(df['SUSP_AGE_GROUP'].cast("string").isin(['<18', '18-24', '25-44', '45-64', '65+', 'UNKNOWN']).desc())
df = df.withColumn('OFNS_CATS', df['OFNS_CATS'].cast('string').cast('string')
                   .cast("string")).orderBy(df['OFNS_CATS'].cast("string").isin(['PROPERTY', 'PERSONAL', 'SEXUAL', 'ADMINISTRATIVE', 'DRUGS/ALCOHOL', 'OTHER']).desc())

# %%
from pyspark.sql.functions import col, to_date, to_timestamp

# Convert string columns to date and timestamp types
df = df.withColumn('CMPLNT_FR_DT', to_date(col('CMPLNT_FR_DT'), 'MM/dd/yyyy'))
df = df.withColumn('RPT_DT', to_date(col('RPT_DT'), 'MM/dd/yyyy'))


# Convert string columns to integer types
int_cols = ['ADDR_PCT_CD', 'KY_CD', 'PD_CD', 'JURISDICTION_CODE', 'X_COORD_CD', 'Y_COORD_CD']
for col_name in int_cols:
    df = df.withColumn(col_name, col(col_name).cast('integer'))

# %%
df = df.drop("JURISDICTION_CODE", "JURIS_DESC")

# %%
df.printSchema()
# Out:
# root
#  |-- CMPLNT_NUM: integer (nullable = true)
#  |-- CMPLNT_FR_DT: date (nullable = true)
#  |-- CMPLNT_FR_TM: string (nullable = true)
#  |-- ADDR_PCT_CD: integer (nullable = true)
#  |-- RPT_DT: date (nullable = true)
#  |-- KY_CD: integer (nullable = true)
#  |-- OFNS_DESC: string (nullable = false)
#  |-- PD_CD: integer (nullable = true)
#  |-- PD_DESC: string (nullable = false)
#  |-- CRM_ATPT_CPTD_CD: string (nullable = false)
#  |-- LAW_CAT_CD: string (nullable = false)
#  |-- BORO_NM: string (nullable = false)
#  |-- LOC_OF_OCCUR_DESC: string (nullable = false)
#  |-- PREM_TYP_DESC: string (nullable = false)
#  |-- X_COORD_CD: integer (nullable = true)
#  |-- Y_COORD_CD: integer (nullable = true)
#  |-- SUSP_AGE_GROUP: string (nullable = false)
#  |-- SUSP_RACE: string (nullable = false)
#  |-- SUSP_SEX: string (nullable = false)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Lat_Lon: string (nullable = false)
#  |-- PATROL_BORO: string (nullable = false)
#  |-- VIC_AGE_GROUP: string (nullable = false)
#  |-- VIC_RACE: string (nullable = false)
#  |-- VIC_SEX: string (nullable = false)
#  |-- CMPLNT_FR_TM_double: string (nullable = true)
#  |-- OFNS_CATS: string (nullable = false)

# %% [markdown]
# ## Merge with nyc neighbourhoods( add neighbourhood col in original dataset )

# %%
import requests
url = 'https://cocl.us/new_york_dataset'
response = requests.get(url)
newyork_data = response.json()

# extract neighborhoods data
neighborhoods_data = newyork_data['features']

# create a list of dictionaries to store the data
neighborhoods_list = []

# populate list with neighborhoods data
for data in neighborhoods_data:
    borough = data['properties']['borough']
    neighborhood_name = data['properties']['name']
    neighborhood_lat = data['geometry']['coordinates'][1]
    neighborhood_lon = data['geometry']['coordinates'][0]
    neighborhoods_list.append({'Borough': borough,
                               'Neighborhood': neighborhood_name,
                               'Latitude': neighborhood_lat,
                               'Longitude': neighborhood_lon})

# create a DataFrame from the list of dictionaries
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
schema = StructType([
    StructField('Borough', StringType(), True),
    StructField('Neighborhood', StringType(), True),
    StructField('Latitude', DoubleType(), True),
    StructField('Longitude', DoubleType(), True)
])
neighborhoodsDF = spark.createDataFrame(neighborhoods_list, schema=schema)

df.show()
neighborhoodsDF.show()
# Out:
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+--------------------+----------+----------+--------------+--------------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------------+--------------------+--------------+
# |CMPLNT_NUM|CMPLNT_FR_DT|       CMPLNT_FR_TM|ADDR_PCT_CD|    RPT_DT|KY_CD|           OFNS_DESC|PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD| LAW_CAT_CD|  BORO_NM|LOC_OF_OCCUR_DESC|       PREM_TYP_DESC|X_COORD_CD|Y_COORD_CD|SUSP_AGE_GROUP|     SUSP_RACE|SUSP_SEX|          Latitude|         Longitude|             Lat_Lon|         PATROL_BORO|VIC_AGE_GROUP|            VIC_RACE|             VIC_SEX|     OFNS_CATS|
# +----------+------------+-------------------+-----------+----------+-----+--------------------+-----+--------------------+----------------+-----------+---------+-----------------+--------------------+----------+----------+--------------+--------------+--------+------------------+------------------+--------------------+--------------------+-------------+--------------------+--------------------+--------------+
# | 916250318|  2015-09-20|2023-05-08 16:45:00|         90|2015-09-20|  361|OFF. AGNST PUB OR...|  639|AGGRAVATED HARASS...|       COMPLETED|MISDEMEANOR| BROOKLYN|           INSIDE|RESIDENCE - APT. ...|    998177|    197814|       UNKNOWN|       UNKNOWN| UNKNOWN|      40.709627746|     -73.949767122|(40.709627746, -7...|PATROL BORO BKLYN...|        45-64|      BLACK HISPANIC|              FEMALE|ADMINISTRATIVE|
# | 344123822|  2010-09-08|2023-05-08 16:00:00|         43|2010-09-08|  344|ASSAULT 3 & RELAT...|  101|           ASSAULT 3|       COMPLETED|MISDEMEANOR|    BRONX|           INSIDE|RESIDENCE - APT. ...|   1023548|    238402|         18-24|WHITE HISPANIC|    MALE|      40.820954868|     -73.858017409|(40.820954868, -7...|   PATROL BORO BRONX|        18-24|      WHITE HISPANIC|              FEMALE|      PERSONAL|
# | 691335970|  2007-11-21|2023-05-08 23:00:00|         81|2007-11-21|  106|      FELONY ASSAULT|  109|ASSAULT 2,1,UNCLA...|       ATTEMPTED|     FELONY| BROOKLYN|         FRONT OF|      GROCERY/BODEGA|   1002194|    191297|       UNKNOWN|       UNKNOWN| UNKNOWN|      40.691732872|     -73.935295276|(40.691732872, -7...|PATROL BORO BKLYN...|      UNKNOWN|             UNKNOWN|BUSINESS/ORGANIZA...|      PERSONAL|
------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col, lower

neighborCrimeDF = df.join(
    neighborhoodsDF.select([
        "Borough",
        "Neighborhood",
        col("Latitude").alias("NLatitude"),
        col("Longitude").alias("NLongitude")
    ]),
    lower(df.BORO_NM) == lower(neighborhoodsDF.Borough),
    "left"
)
neighborCrimeDF.show()
# Out:
# +----------+------------+-------------------+-----------+----------+-----+-----------------+-----+--------------------+----------------+----------+-------+-----------------+-------------+----------+----------+--------------+---------+--------+-----------+-------------+--------------------+-----------------+-------------+--------+-------+---------+-------+-------------------+------------------+------------------+
# |CMPLNT_NUM|CMPLNT_FR_DT|       CMPLNT_FR_TM|ADDR_PCT_CD|    RPT_DT|KY_CD|        OFNS_DESC|PD_CD|             PD_DESC|CRM_ATPT_CPTD_CD|LAW_CAT_CD|BORO_NM|LOC_OF_OCCUR_DESC|PREM_TYP_DESC|X_COORD_CD|Y_COORD_CD|SUSP_AGE_GROUP|SUSP_RACE|SUSP_SEX|   Latitude|    Longitude|             Lat_Lon|      PATROL_BORO|VIC_AGE_GROUP|VIC_RACE|VIC_SEX|OFNS_CATS|Borough|       Neighborhood|         NLatitude|        NLongitude|
# +----------+------------+-------------------+-----------+----------+-----+-----------------+-----+--------------------+----------------+----------+-------+-----------------+-------------+----------+----------+--------------+---------+--------+-----------+-------------+--------------------+-----------------+-------------+--------+-------+---------+-------+-------------------+------------------+------------------+
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|Kingsbridge Heights|  40.8703923914147|-73.90152264513144|
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|           Allerton| 40.86578787802982|-73.85931863221647|
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|          Bronxdale| 40.85272297633017|-73.86172577555115|
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|    North Riverdale| 40.90854282950666|-73.90453054908927|
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|     Spuyten Duyvil| 40.88139497727086|-73.91719048210393|
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|            Belmont| 40.85727710073895|-73.88845196134804|
# | 751236093|  2013-06-19|2023-05-08 16:30:00|         40|2013-06-19|  118|DANGEROUS WEAPONS|  793|WEAPONS POSSESSION 3|       COMPLETED|    FELONY|  BRONX|          UNKNOWN|       STREET|   1004972|    234409|       UNKNOWN|  UNKNOWN| UNKNOWN|40.81005831|-73.925144953|(40.81005831, -73...|PATROL BORO BRONX|      UNKNOWN| UNKNOWN|UNKNOWN| PERSONAL|  Bronx|        Morris Park|40.847549063536334|-73.85040178030421|
# +----------+------------+-------------------+-----------+----------+-----+-----------------+-----+--------------------+----------------+----------+-------+-----------------+-------------+----------+----------+--------------+---------+--------+-----------+-------------+--------------------+-----------------+-------------+--------+-------+---------+-------+-------------------+------------------+------------------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, ArrayType
from haversine import haversine
from pyspark.sql.window import Window
from pyspark.sql.functions import udf

# define UDFs to calculate distance using haversine formula
udf_haversine = udf(lambda x, y: haversine(x, y, unit='mi') if x is not None and y is not None else None, DoubleType())
udf_string2array = udf(lambda lat, long: [float(lat), float(long)] if lat is not None and long is not None else None, ArrayType(DoubleType()))

# create new columns with latitude and longitude as arrays, and distance between crime location and neighborhood
neighborCrimeDF2 = neighborCrimeDF \
    .withColumn("LatLong", udf_string2array("Latitude", "Longitude")) \
    .withColumn("NLatLong", udf_string2array("NLatitude", "NLongitude")) \
    .withColumn("Distance", udf_haversine("LatLong", "NLatLong"))

# use window function to get the nearest neighborhood for each crime
window = Window.partitionBy("CMPLNT_NUM").orderBy(F.col("Distance").asc())
NCDF = neighborCrimeDF2 \
    .withColumn("DistanceRank", F.rank().over(window)) \
    .filter(F.col("DistanceRank") == 1)

# %% [markdown]
# ## Store cleaned data to mongoDB database for analysis

# %%
rows = NCDF.rdd.map(lambda row: row.asDict()).collect()

# %%
for row in rows:
    row['RPT_DT'] = row['RPT_DT'].isoformat()

# %%
from pyspark.sql import SparkSession
import pymongo
from bson import json_util

client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["NYPD"]
collection = db["NYPD_Cleaned"]

# %%
collection.insert_many(rows)

# %% [markdown]
# ### DATA ANALYSIS

# %%
count = collection.count_documents({})
print("Total count of documents in the collection:", count)
# Out:
# Total count of documents in the collection: 1945750

# %%
import pprint
pprint.pprint(rows[0], depth=1, width=80)
# Out:
# {'ADDR_PCT_CD': 108,
#  'BORO_NM': 'QUEENS',
#  'Borough': 'Queens',
#  'CMPLNT_FR_DT': datetime.date(2014, 1, 14),
#  'CMPLNT_FR_TM': '2023-05-08 00:25:00',
#  'CMPLNT_NUM': 100208792,
#  'CRM_ATPT_CPTD_CD': 'COMPLETED',
#  'Distance': 0.15462914324868482,
#  'DistanceRank': 1,
#  'KY_CD': 351,
#  'LAW_CAT_CD': 'MISDEMEANOR',
#  'LOC_OF_OCCUR_DESC': 'INSIDE',
#  'LatLong': [...],
#  'Lat_Lon': '(40.748580841, -73.902061752)',
#  'Latitude': 40.748580841,
#  'Longitude': -73.902061752,
#  'NLatLong': [...],
#  'NLatitude': 40.74634908860222,
#  'NLongitude': -73.90184166838284,
#  'Neighborhood': 'Woodside',
#  'OFNS_CATS': 'PROPERTY',
#  'OFNS_DESC': 'CRIMINAL MISCHIEF & RELATED OF',
#  'PATROL_BORO': 'PATROL BORO QUEENS NORTH',
#  'PD_CD': 259,
#  'PD_DESC': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#  'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE',
#  'RPT_DT': datetime.date(2014, 1, 14),
#  'SUSP_AGE_GROUP': 'UNKNOWN',
#  'SUSP_RACE': 'WHITE HISPANIC',
#  'SUSP_SEX': 'MALE',
#  'VIC_AGE_GROUP': '25-44',
#  'VIC_RACE': 'WHITE HISPANIC',
#  'VIC_SEX': 'MALE',
#  'X_COORD_CD': 1011387,
#  'Y_COORD_CD': 212017,
#  '_id': ObjectId('6459872efa42a60e401075f4')}

# %%
first_doc = collection.find_one()
print(first_doc)
# Out:
# {'_id': ObjectId('6459872efa42a60e401075f4'), 'CMPLNT_NUM': 100208792, 'CMPLNT_FR_DT': '2014-01-14', 'CMPLNT_FR_TM': '2023-05-08 00:25:00', 'ADDR_PCT_CD': 108, 'RPT_DT': '2014-01-14', 'KY_CD': 351, 'OFNS_DESC': 'CRIMINAL MISCHIEF & RELATED OF', 'PD_CD': 259, 'PD_DESC': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4', 'CRM_ATPT_CPTD_CD': 'COMPLETED', 'LAW_CAT_CD': 'MISDEMEANOR', 'BORO_NM': 'QUEENS', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'X_COORD_CD': 1011387, 'Y_COORD_CD': 212017, 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'MALE', 'Latitude': 40.748580841, 'Longitude': -73.902061752, 'Lat_Lon': '(40.748580841, -73.902061752)', 'PATROL_BORO': 'PATROL BORO QUEENS NORTH', 'VIC_AGE_GROUP': '25-44', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'MALE', 'OFNS_CATS': 'PROPERTY', 'Borough': 'Queens', 'Neighborhood': 'Woodside', 'NLatitude': 40.74634908860222, 'NLongitude': -73.90184166838284, 'LatLong': [40.748580841, -73.902061752], 'NLatLong': [40.74634908860222, -73.90184166838284], 'Distance': 0.15462914324868482, 'DistanceRank': 1}

# %% [markdown]
# ### How many crimes were reported in each borough?

# %%
result = collection.aggregate([
    {"$group": {"_id": "$BORO_NM", "count": {"$sum": 1}}}
])

for document in result:
    print(document)
# Out:
# {'_id': 'BROOKLYN', 'count': 576764}
# {'_id': 'MANHATTAN', 'count': 468537}
# {'_id': 'QUEENS', 'count': 389085}
# {'_id': 'STATEN ISLAND', 'count': 90033}
# {'_id': 'BRONX', 'count': 421331}

# %% [markdown]
# ### To analyze the number of crimes reported in different boroughs over time:

# %%
result = collection.aggregate([
    {"$group": {"_id": {"borough": "$BORO_NM", "year": {"$year": {"$dateFromString": {"dateString": "$CMPLNT_FR_DT"}}}}, "count": {"$sum": 1}}}
])

for document in result:
    print(document)
# Out:
# {'_id': {'borough': 'MANHATTAN', 'year': 2011}, 'count': 28865}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2009}, 'count': 6035}
# {'_id': {'borough': 'BROOKLYN', 'year': 1919}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2018}, 'count': 25396}
# {'_id': {'borough': 'BROOKLYN', 'year': 1955}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2016}, 'count': 23784}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1978}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1912}, 'count': 2}
# {'_id': {'borough': 'BROOKLYN', 'year': 1969}, 'count': 2}
# {'_id': {'borough': 'BROOKLYN', 'year': 1993}, 'count': 7}
# {'_id': {'borough': 'QUEENS', 'year': 2007}, 'count': 26326}
# {'_id': {'borough': 'BROOKLYN', 'year': 1962}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2015}, 'count': 28060}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2002}, 'count': 6}
# {'_id': {'borough': 'MANHATTAN', 'year': 2008}, 'count': 31902}
# {'_id': {'borough': 'BRONX', 'year': 1968}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1998}, 'count': 18}
# {'_id': {'borough': 'BROOKLYN', 'year': 2000}, 'count': 73}
# {'_id': {'borough': 'BRONX', 'year': 1992}, 'count': 7}
# {'_id': {'borough': 'BROOKLYN', 'year': 1019}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1017}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1905}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1984}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2007}, 'count': 38837}
# {'_id': {'borough': 'QUEENS', 'year': 2005}, 'count': 578}
# {'_id': {'borough': 'BRONX', 'year': 2001}, 'count': 63}
# {'_id': {'borough': 'QUEENS', 'year': 1981}, 'count': 2}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2016}, 'count': 5525}
# {'_id': {'borough': 'MANHATTAN', 'year': 2001}, 'count': 68}
# {'_id': {'borough': 'MANHATTAN', 'year': 1977}, 'count': 2}
# {'_id': {'borough': 'MANHATTAN', 'year': 1016}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1940}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1994}, 'count': 3}
# {'_id': {'borough': 'BROOKLYN', 'year': 1983}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2010}, 'count': 27710}
# {'_id': {'borough': 'QUEENS', 'year': 1996}, 'count': 10}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2001}, 'count': 20}
# {'_id': {'borough': 'MANHATTAN', 'year': 1970}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1989}, 'count': 3}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2008}, 'count': 6674}
# {'_id': {'borough': 'BROOKLYN', 'year': 1990}, 'count': 6}
# {'_id': {'borough': 'BROOKLYN', 'year': 2014}, 'count': 37556}
# {'_id': {'borough': 'BRONX', 'year': 1958}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1987}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1028}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1994}, 'count': 3}
# {'_id': {'borough': 'QUEENS', 'year': 2015}, 'count': 23708}
# {'_id': {'borough': 'BROOKLYN', 'year': 2021}, 'count': 30820}
# {'_id': {'borough': 'BROOKLYN', 'year': 1918}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1913}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1991}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1954}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1917}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1015}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2006}, 'count': 25272}
# {'_id': {'borough': 'MANHATTAN', 'year': 2016}, 'count': 29022}
# {'_id': {'borough': 'BRONX', 'year': 1976}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1955}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2009}, 'count': 30970}
# {'_id': {'borough': 'BRONX', 'year': 2000}, 'count': 52}
# {'_id': {'borough': 'BROOKLYN', 'year': 1968}, 'count': 3}
# {'_id': {'borough': 'MANHATTAN', 'year': 1985}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2013}, 'count': 25112}
# {'_id': {'borough': 'BROOKLYN', 'year': 1992}, 'count': 4}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1948}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2009}, 'count': 28223}
# {'_id': {'borough': 'BROOKLYN', 'year': 1982}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2004}, 'count': 108}
# {'_id': {'borough': 'MANHATTAN', 'year': 1978}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1999}, 'count': 27}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1029}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1015}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2015}, 'count': 5575}
# {'_id': {'borough': 'MANHATTAN', 'year': 2002}, 'count': 44}
# {'_id': {'borough': 'QUEENS', 'year': 1980}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2013}, 'count': 37308}
# {'_id': {'borough': 'BRONX', 'year': 2011}, 'count': 27028}
# {'_id': {'borough': 'QUEENS', 'year': 1995}, 'count': 10}
# {'_id': {'borough': 'QUEENS', 'year': 1971}, 'count': 4}
# {'_id': {'borough': 'BROOKLYN', 'year': 2006}, 'count': 38283}
# {'_id': {'borough': 'MANHATTAN', 'year': 1989}, 'count': 4}
# {'_id': {'borough': 'BROOKLYN', 'year': 1027}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2013}, 'count': 29421}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2000}, 'count': 6}
# {'_id': {'borough': 'BROOKLYN', 'year': 2020}, 'count': 29737}
# {'_id': {'borough': 'BRONX', 'year': 2020}, 'count': 22715}
# {'_id': {'borough': 'MANHATTAN', 'year': 2006}, 'count': 30398}
# {'_id': {'borough': 'QUEENS', 'year': 1986}, 'count': 4}
# {'_id': {'borough': 'BROOKLYN', 'year': 1917}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1960}, 'count': 3}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1993}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1982}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2014}, 'count': 25020}
# {'_id': {'borough': 'MANHATTAN', 'year': 1975}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1967}, 'count': 2}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2014}, 'count': 5569}
# {'_id': {'borough': 'BRONX', 'year': 1985}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1916}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1999}, 'count': 19}
# {'_id': {'borough': 'BROOKLYN', 'year': 1991}, 'count': 3}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2021}, 'count': 4610}
# {'_id': {'borough': 'QUEENS', 'year': 2021}, 'count': 24021}
# {'_id': {'borough': 'MANHATTAN', 'year': 1992}, 'count': 4}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2007}, 'count': 6464}
# {'_id': {'borough': 'BRONX', 'year': 1970}, 'count': 3}
# {'_id': {'borough': 'BROOKLYN', 'year': 1998}, 'count': 20}
# {'_id': {'borough': 'BRONX', 'year': 1018}, 'count': 2}
# {'_id': {'borough': 'BROOKLYN', 'year': 1018}, 'count': 3}
# {'_id': {'borough': 'QUEENS', 'year': 2012}, 'count': 24602}
# {'_id': {'borough': 'BRONX', 'year': 1994}, 'count': 3}
# {'_id': {'borough': 'MANHATTAN', 'year': 1968}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2021}, 'count': 27353}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1992}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 2003}, 'count': 82}
# {'_id': {'borough': 'BROOKLYN', 'year': 1945}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1979}, 'count': 2}
# {'_id': {'borough': 'BRONX', 'year': 2019}, 'count': 25093}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1968}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1028}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1994}, 'count': 6}
# {'_id': {'borough': 'BROOKLYN', 'year': 1981}, 'count': 4}
# {'_id': {'borough': 'BROOKLYN', 'year': 2005}, 'count': 815}
# {'_id': {'borough': 'BRONX', 'year': 1914}, 'count': 2}
# {'_id': {'borough': 'MANHATTAN', 'year': 1990}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1970}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2014}, 'count': 28322}
# {'_id': {'borough': 'QUEENS', 'year': 1985}, 'count': 3}
# {'_id': {'borough': 'MANHATTAN', 'year': 2007}, 'count': 32718}
# {'_id': {'borough': 'BROOKLYN', 'year': 1988}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1961}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2012}, 'count': 38601}
# {'_id': {'borough': 'BROOKLYN', 'year': 1909}, 'count': 2}
# {'_id': {'borough': 'BRONX', 'year': 1984}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1983}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2019}, 'count': 32920}
# {'_id': {'borough': 'MANHATTAN', 'year': 1976}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1916}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2013}, 'count': 5634}
# {'_id': {'borough': 'MANHATTAN', 'year': 1019}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2000}, 'count': 51}
# {'_id': {'borough': 'BRONX', 'year': 1993}, 'count': 3}
# {'_id': {'borough': 'QUEENS', 'year': 2020}, 'count': 22273}
# {'_id': {'borough': 'MANHATTAN', 'year': 1993}, 'count': 7}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1999}, 'count': 6}
# {'_id': {'borough': 'BROOKLYN', 'year': 1973}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2002}, 'count': 56}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2006}, 'count': 6613}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1982}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1966}, 'count': 5}
# {'_id': {'borough': 'QUEENS', 'year': 2011}, 'count': 24386}
# {'_id': {'borough': 'BROOKLYN', 'year': 1980}, 'count': 2}
# {'_id': {'borough': 'MANHATTAN', 'year': 2004}, 'count': 127}
# {'_id': {'borough': 'MANHATTAN', 'year': 1021}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2004}, 'count': 158}
# {'_id': {'borough': 'BRONX', 'year': 1015}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2002}, 'count': 63}
# {'_id': {'borough': 'BRONX', 'year': 2004}, 'count': 110}
# {'_id': {'borough': 'BROOKLYN', 'year': 1997}, 'count': 12}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1991}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1967}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2020}, 'count': 4230}
# {'_id': {'borough': 'BROOKLYN', 'year': 1987}, 'count': 5}
# {'_id': {'borough': 'BROOKLYN', 'year': 2011}, 'count': 37981}
# {'_id': {'borough': 'MANHATTAN', 'year': 1973}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1997}, 'count': 5}
# {'_id': {'borough': 'BRONX', 'year': 2013}, 'count': 25913}
# {'_id': {'borough': 'QUEENS', 'year': 1993}, 'count': 3}
# {'_id': {'borough': 'MANHATTAN', 'year': 1966}, 'count': 3}
# {'_id': {'borough': 'QUEENS', 'year': 1984}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2006}, 'count': 26631}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2005}, 'count': 125}
# {'_id': {'borough': 'BRONX', 'year': 1917}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1915}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1910}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2018}, 'count': 34024}
# {'_id': {'borough': 'BRONX', 'year': 2015}, 'count': 26324}
# {'_id': {'borough': 'MANHATTAN', 'year': 2019}, 'count': 28946}
# {'_id': {'borough': 'BROOKLYN', 'year': 1965}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2019}, 'count': 22984}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1998}, 'count': 5}
# {'_id': {'borough': 'BROOKLYN', 'year': 1922}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1996}, 'count': 11}
# {'_id': {'borough': 'QUEENS', 'year': 1905}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1988}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2003}, 'count': 89}
# {'_id': {'borough': 'MANHATTAN', 'year': 1909}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2010}, 'count': 24678}
# {'_id': {'borough': 'MANHATTAN', 'year': 2012}, 'count': 29771}
# {'_id': {'borough': 'MANHATTAN', 'year': 2005}, 'count': 639}
# {'_id': {'borough': 'BRONX', 'year': 2012}, 'count': 26590}
# {'_id': {'borough': 'BROOKLYN', 'year': 1972}, 'count': 3}
# {'_id': {'borough': 'QUEENS', 'year': 1977}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 2001}, 'count': 49}
# {'_id': {'borough': 'MANHATTAN', 'year': 1938}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1986}, 'count': 3}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2012}, 'count': 5948}
# {'_id': {'borough': 'MANHATTAN', 'year': 1981}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2021}, 'count': 23058}
# {'_id': {'borough': 'BROOKLYN', 'year': 1979}, 'count': 1}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2019}, 'count': 4601}
# {'_id': {'borough': 'BRONX', 'year': 1916}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1018}, 'count': 3}
# {'_id': {'borough': 'BROOKLYN', 'year': 2003}, 'count': 132}
# {'_id': {'borough': 'MANHATTAN', 'year': 1998}, 'count': 10}
# {'_id': {'borough': 'QUEENS', 'year': 1992}, 'count': 3}
# {'_id': {'borough': 'BRONX', 'year': 2014}, 'count': 26283}
# {'_id': {'borough': 'BROOKLYN', 'year': 2017}, 'count': 34155}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2004}, 'count': 37}
# {'_id': {'borough': 'BROOKLYN', 'year': 2010}, 'count': 37772}
# {'_id': {'borough': 'BRONX', 'year': 1986}, 'count': 2}
# {'_id': {'borough': 'MANHATTAN', 'year': 1991}, 'count': 3}
# {'_id': {'borough': 'QUEENS', 'year': 1983}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1918}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1995}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2020}, 'count': 24514}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1997}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 2018}, 'count': 22586}
# {'_id': {'borough': 'MANHATTAN', 'year': 1995}, 'count': 6}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2018}, 'count': 5141}
# {'_id': {'borough': 'BROOKLYN', 'year': 1971}, 'count': 4}
# {'_id': {'borough': 'BRONX', 'year': 1973}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2009}, 'count': 24478}
# {'_id': {'borough': 'BRONX', 'year': 1997}, 'count': 9}
# {'_id': {'borough': 'BRONX', 'year': 1966}, 'count': 2}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1987}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2002}, 'count': 108}
# {'_id': {'borough': 'QUEENS', 'year': 1021}, 'count': 3}
# {'_id': {'borough': 'BRONX', 'year': 1990}, 'count': 3}
# {'_id': {'borough': 'BROOKLYN', 'year': 1995}, 'count': 9}
# {'_id': {'borough': 'QUEENS', 'year': 2000}, 'count': 49}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2011}, 'count': 5921}
# {'_id': {'borough': 'BRONX', 'year': 1999}, 'count': 17}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1996}, 'count': 2}
# {'_id': {'borough': 'BROOKLYN', 'year': 1906}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2017}, 'count': 28440}
# {'_id': {'borough': 'BROOKLYN', 'year': 2009}, 'count': 37358}
# {'_id': {'borough': 'BRONX', 'year': 1975}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1991}, 'count': 4}
# {'_id': {'borough': 'MANHATTAN', 'year': 1950}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1985}, 'count': 2}
# {'_id': {'borough': 'MANHATTAN', 'year': 2010}, 'count': 30105}
# {'_id': {'borough': 'BROOKLYN', 'year': 1913}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 2008}, 'count': 28309}
# {'_id': {'borough': 'MANHATTAN', 'year': 1986}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 1982}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2016}, 'count': 35329}
# {'_id': {'borough': 'BRONX', 'year': 2017}, 'count': 25820}
# {'_id': {'borough': 'BRONX', 'year': 1996}, 'count': 4}
# {'_id': {'borough': 'QUEENS', 'year': 2017}, 'count': 22801}
# {'_id': {'borough': 'MANHATTAN', 'year': 2003}, 'count': 77}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2010}, 'count': 6044}
# {'_id': {'borough': 'MANHATTAN', 'year': 1979}, 'count': 2}
# {'_id': {'borough': 'MANHATTAN', 'year': 1996}, 'count': 6}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2017}, 'count': 5210}
# {'_id': {'borough': 'BRONX', 'year': 2005}, 'count': 428}
# {'_id': {'borough': 'BROOKLYN', 'year': 1920}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1017}, 'count': 1}
# {'_id': {'borough': 'QUEENS', 'year': 2008}, 'count': 25993}
# {'_id': {'borough': 'BROOKLYN', 'year': 1994}, 'count': 6}
# {'_id': {'borough': 'BRONX', 'year': 1981}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1016}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1026}, 'count': 2}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 2003}, 'count': 14}
# {'_id': {'borough': 'MANHATTAN', 'year': 1965}, 'count': 1}
# {'_id': {'borough': 'BRONX', 'year': 1974}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1970}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1999}, 'count': 27}
# {'_id': {'borough': 'BRONX', 'year': 1998}, 'count': 8}
# {'_id': {'borough': 'QUEENS', 'year': 1975}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1010}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1984}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 1977}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1915}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 2018}, 'count': 28615}
# {'_id': {'borough': 'BRONX', 'year': 2007}, 'count': 29018}
# {'_id': {'borough': 'STATEN ISLAND', 'year': 1995}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2001}, 'count': 110}
# {'_id': {'borough': 'QUEENS', 'year': 1990}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1966}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2015}, 'count': 35582}
# {'_id': {'borough': 'BRONX', 'year': 2016}, 'count': 26334}
# {'_id': {'borough': 'BROOKLYN', 'year': 1912}, 'count': 1}
# {'_id': {'borough': 'BROOKLYN', 'year': 2008}, 'count': 38926}
# {'_id': {'borough': 'BROOKLYN', 'year': 1029}, 'count': 1}
# {'_id': {'borough': 'MANHATTAN', 'year': 1987}, 'count': 2}
# {'_id': {'borough': 'QUEENS', 'year': 1997}, 'count': 12}
# {'_id': {'borough': 'QUEENS', 'year': 1920}, 'count': 1}

# %% [markdown]
# ### To analyze trends in the types of crimes reported and the level of offense:

# %%
result = collection.aggregate([
    {"$group": {"_id": {"offense": "$OFNS_DESC", "level": "$LAW_CAT_CD"}, "count": {"$sum": 1}}},
    {"$sort": {"_id.offense": 1}}
])

for document in result:
    print(document)
# Out:
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'level': 'VIOLATION'}, 'count': 461}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'level': 'MISDEMEANOR'}, 'count': 3834}
# {'_id': {'offense': 'ADMINISTRATIVE CODES', 'level': 'VIOLATION'}, 'count': 2}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'level': 'MISDEMEANOR'}, 'count': 199}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'level': 'MISDEMEANOR'}, 'count': 359}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'level': 'MISDEMEANOR'}, 'count': 34}
# {'_id': {'offense': 'ARSON', 'level': 'FELONY'}, 'count': 4561}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'level': 'MISDEMEANOR'}, 'count': 204821}
# {'_id': {'offense': "BURGLAR'S TOOLS", 'level': 'MISDEMEANOR'}, 'count': 985}
# {'_id': {'offense': 'BURGLARY', 'level': 'FELONY'}, 'count': 66423}
# {'_id': {'offense': 'CHILD ABANDONMENT/NON SUPPORT', 'level': 'FELONY'}, 'count': 113}
# {'_id': {'offense': 'CRIMINAL MISCHIEF & RELATED OF', 'level': 'FELONY'}, 'count': 34608}
# {'_id': {'offense': 'CRIMINAL MISCHIEF & RELATED OF', 'level': 'MISDEMEANOR'}, 'count': 162783}
# {'_id': {'offense': 'CRIMINAL TRESPASS', 'level': 'MISDEMEANOR'}, 'count': 20922}
# {'_id': {'offense': 'DANGEROUS DRUGS', 'level': 'MISDEMEANOR'}, 'count': 86617}
# {'_id': {'offense': 'DANGEROUS DRUGS', 'level': 'FELONY'}, 'count': 22105}
# {'_id': {'offense': 'DANGEROUS WEAPONS', 'level': 'FELONY'}, 'count': 19172}
# {'_id': {'offense': 'DANGEROUS WEAPONS', 'level': 'MISDEMEANOR'}, 'count': 22444}
# {'_id': {'offense': 'DISORDERLY CONDUCT', 'level': 'VIOLATION'}, 'count': 272}
# {'_id': {'offense': 'DISRUPTION OF A RELIGIOUS SERV', 'level': 'MISDEMEANOR'}, 'count': 15}
# {'_id': {'offense': 'ENDAN WELFARE INCOMP', 'level': 'FELONY'}, 'count': 26}
# {'_id': {'offense': 'ENDAN WELFARE INCOMP', 'level': 'MISDEMEANOR'}, 'count': 43}
# {'_id': {'offense': 'ESCAPE 3', 'level': 'MISDEMEANOR'}, 'count': 48}
# {'_id': {'offense': 'FELONY ASSAULT', 'level': 'FELONY'}, 'count': 77020}
# {'_id': {'offense': 'FELONY SEX CRIMES', 'level': 'FELONY'}, 'count': 8}
# {'_id': {'offense': 'FORGERY', 'level': 'FELONY'}, 'count': 19143}
# {'_id': {'offense': 'FORTUNE TELLING', 'level': 'MISDEMEANOR'}, 'count': 1}
# {'_id': {'offense': 'FRAUDS', 'level': 'MISDEMEANOR'}, 'count': 11824}
# {'_id': {'offense': 'FRAUDULENT ACCOSTING', 'level': 'MISDEMEANOR'}, 'count': 806}
# {'_id': {'offense': 'GAMBLING', 'level': 'MISDEMEANOR'}, 'count': 770}
# {'_id': {'offense': 'GAMBLING', 'level': 'FELONY'}, 'count': 27}
# {'_id': {'offense': 'GRAND LARCENY', 'level': 'FELONY'}, 'count': 169387}
# {'_id': {'offense': 'GRAND LARCENY OF MOTOR VEHICLE', 'level': 'FELONY'}, 'count': 35823}
# {'_id': {'offense': 'HARRASSMENT 2', 'level': 'VIOLATION'}, 'count': 254461}
# {'_id': {'offense': 'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'level': 'FELONY'}, 'count': 49}
# {'_id': {'offense': 'HOMICIDE-NEGLIGENT-VEHICLE', 'level': 'FELONY'}, 'count': 19}
# {'_id': {'offense': 'INTOXICATED & IMPAIRED DRIVING', 'level': 'MISDEMEANOR'}, 'count': 24764}
# {'_id': {'offense': 'INTOXICATED/IMPAIRED DRIVING', 'level': 'FELONY'}, 'count': 14}
# {'_id': {'offense': 'JOSTLING', 'level': 'MISDEMEANOR'}, 'count': 109}
# {'_id': {'offense': 'KIDNAPPING', 'level': 'FELONY'}, 'count': 16}
# {'_id': {'offense': 'KIDNAPPING & RELATED OFFENSES', 'level': 'FELONY'}, 'count': 759}
# {'_id': {'offense': 'LOITERING', 'level': 'VIOLATION'}, 'count': 5}
# {'_id': {'offense': 'LOITERING FOR DRUG PURPOSES', 'level': 'MISDEMEANOR'}, 'count': 6}
# {'_id': {'offense': 'LOITERING/DEVIATE SEX', 'level': 'VIOLATION'}, 'count': 4}
# {'_id': {'offense': 'LOITERING/GAMBLING (CARDS, DIC', 'level': 'VIOLATION'}, 'count': 60}
# {'_id': {'offense': 'MISCELLANEOUS PENAL LAW', 'level': 'FELONY'}, 'count': 46997}
# {'_id': {'offense': 'MISCELLANEOUS PENAL LAW', 'level': 'VIOLATION'}, 'count': 2901}
# {'_id': {'offense': 'NEW YORK CITY HEALTH CODE', 'level': 'MISDEMEANOR'}, 'count': 10}
# {'_id': {'offense': 'NEW YORK CITY HEALTH CODE', 'level': 'VIOLATION'}, 'count': 7}
# {'_id': {'offense': 'NYS LAWS-UNCLASSIFIED FELONY', 'level': 'FELONY'}, 'count': 1830}
# {'_id': {'offense': 'NYS LAWS-UNCLASSIFIED VIOLATION', 'level': 'VIOLATION'}, 'count': 13}
# {'_id': {'offense': 'OFF. AGNST PUB ORD SENSBLTY &', 'level': 'MISDEMEANOR'}, 'count': 99789}
# {'_id': {'offense': 'OFFENSES AGAINST MARRIAGE UNCL', 'level': 'MISDEMEANOR'}, 'count': 1}
# {'_id': {'offense': 'OFFENSES AGAINST PUBLIC ADMINI', 'level': 'MISDEMEANOR'}, 'count': 35645}
# {'_id': {'offense': 'OFFENSES AGAINST PUBLIC SAFETY', 'level': 'MISDEMEANOR'}, 'count': 292}
# {'_id': {'offense': 'OFFENSES AGAINST THE PERSON', 'level': 'MISDEMEANOR'}, 'count': 4940}
# {'_id': {'offense': 'OFFENSES INVOLVING FRAUD', 'level': 'MISDEMEANOR'}, 'count': 6380}
# {'_id': {'offense': 'OFFENSES RELATED TO CHILDREN', 'level': 'MISDEMEANOR'}, 'count': 425}
# {'_id': {'offense': 'OTHER OFFENSES RELATED TO THEF', 'level': 'MISDEMEANOR'}, 'count': 4233}
# {'_id': {'offense': 'OTHER STATE LAWS', 'level': 'VIOLATION'}, 'count': 70}
# {'_id': {'offense': 'OTHER STATE LAWS (NON PENAL LA', 'level': 'MISDEMEANOR'}, 'count': 1750}
# {'_id': {'offense': 'OTHER STATE LAWS (NON PENAL LA', 'level': 'FELONY'}, 'count': 44}
# {'_id': {'offense': 'OTHER STATE LAWS (NON PENAL LAW)', 'level': 'MISDEMEANOR'}, 'count': 3}
# {'_id': {'offense': 'OTHER TRAFFIC INFRACTION', 'level': 'VIOLATION'}, 'count': 4}
# {'_id': {'offense': 'PETIT LARCENY', 'level': 'MISDEMEANOR'}, 'count': 332370}
# {'_id': {'offense': 'PETIT LARCENY OF MOTOR VEHICLE', 'level': 'MISDEMEANOR'}, 'count': 370}
# {'_id': {'offense': 'POSSESSION OF STOLEN PROPERTY', 'level': 'MISDEMEANOR'}, 'count': 6234}
# {'_id': {'offense': 'POSSESSION OF STOLEN PROPERTY', 'level': 'FELONY'}, 'count': 3465}
# {'_id': {'offense': 'PROSTITUTION & RELATED OFFENSES', 'level': 'MISDEMEANOR'}, 'count': 275}
# {'_id': {'offense': 'PROSTITUTION & RELATED OFFENSES', 'level': 'FELONY'}, 'count': 69}
# {'_id': {'offense': 'RAPE', 'level': 'FELONY'}, 'count': 5632}
# {'_id': {'offense': 'ROBBERY', 'level': 'FELONY'}, 'count': 70355}
# {'_id': {'offense': 'SEX CRIMES', 'level': 'FELONY'}, 'count': 4840}
# {'_id': {'offense': 'SEX CRIMES', 'level': 'MISDEMEANOR'}, 'count': 18863}
# {'_id': {'offense': 'THEFT OF SERVICES', 'level': 'MISDEMEANOR'}, 'count': 1220}
# {'_id': {'offense': 'THEFT-FRAUD', 'level': 'FELONY'}, 'count': 20058}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'level': 'MISDEMEANOR'}, 'count': 5773}
# {'_id': {'offense': 'UNDER THE INFLUENCE OF DRUGS', 'level': 'VIOLATION'}, 'count': 2}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'level': 'VIOLATION'}, 'count': 19}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'level': 'MISDEMEANOR'}, 'count': 24949}

# %% [markdown]
# ### To map the locations of crimes and identify areas with high crime rates:

# %%
from bson.son import SON

result = collection.aggregate([
    {"$group": {"_id": {"latitude": "$Latitude", "longitude": "$Longitude"}, "count": {"$sum": 1}}},
    {"$sort": SON([("count", -1), ("_id", -1)])},
    {"$limit": 10}
])

for document in result:
    print(document)
# Out:
# {'_id': {'latitude': 40.750430768, 'longitude': -73.989282176}, 'count': 4903}
# {'_id': {'latitude': 40.679700408, 'longitude': -73.776047368}, 'count': 3836}
# {'_id': {'latitude': 40.791151867, 'longitude': -73.884371919}, 'count': 1950}
# {'_id': {'latitude': 40.837323511, 'longitude': -73.919830757}, 'count': 1715}
# {'_id': {'latitude': 40.869058532, 'longitude': -73.879630148}, 'count': 1580}
# {'_id': {'latitude': 40.710093847, 'longitude': -74.01060963}, 'count': 1550}
# {'_id': {'latitude': 40.733926841, 'longitude': -73.871582398}, 'count': 1419}
# {'_id': {'latitude': 40.804384046, 'longitude': -73.937421669}, 'count': 1324}
# {'_id': {'latitude': 40.75043076800005, 'longitude': -73.98928217599996}, 'count': 1282}
# {'_id': {'latitude': 40.671106911, 'longitude': -73.881432957}, 'count': 1281}

# %% [markdown]
# ### To identify the types of locations where crimes tend to occur:

# %%
result = collection.aggregate([
    {"$group": {"_id": "$PREM_TYP_DESC", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
])

for document in result:
    print(document)
# Out:
# {'_id': 'STREET', 'count': 618333}
# {'_id': 'RESIDENCE - APT. HOUSE', 'count': 415758}
# {'_id': 'RESIDENCE-HOUSE', 'count': 192167}
# {'_id': 'RESIDENCE - PUBLIC HOUSING', 'count': 146440}
# {'_id': 'OTHER', 'count': 51244}
# {'_id': 'COMMERCIAL BUILDING', 'count': 49867}
# {'_id': 'CHAIN STORE', 'count': 47085}
# {'_id': 'TRANSIT - NYC SUBWAY', 'count': 41449}
# {'_id': 'DEPARTMENT STORE', 'count': 39132}
# {'_id': 'GROCERY/BODEGA', 'count': 25033}
# {'_id': 'RESTAURANT/DINER', 'count': 22586}
# {'_id': 'PARK/PLAYGROUND', 'count': 21788}
# {'_id': 'PUBLIC SCHOOL', 'count': 21725}
# {'_id': 'BAR/NIGHT CLUB', 'count': 20263}
# {'_id': 'DRUG STORE', 'count': 20096}
# {'_id': 'CLOTHING/BOUTIQUE', 'count': 16292}
# {'_id': 'PUBLIC BUILDING', 'count': 11049}
# {'_id': 'FOOD SUPERMARKET', 'count': 10497}
# {'_id': 'PARKING LOT/GARAGE (PUBLIC)', 'count': 10401}
# {'_id': 'PARKING LOT/GARAGE (PRIVATE)', 'count': 10085}
# {'_id': 'FAST FOOD', 'count': 9644}
# {'_id': 'HOSPITAL', 'count': 9279}
# {'_id': 'HOTEL/MOTEL', 'count': 9141}
# {'_id': 'UNKNOWN', 'count': 8632}
# {'_id': 'STORE UNCLASSIFIED', 'count': 8368}
# {'_id': 'BANK', 'count': 8250}
# {'_id': 'SMALL MERCHANT', 'count': 7787}
# {'_id': 'GYM/FITNESS FACILITY', 'count': 5856}
# {'_id': 'HIGHWAY/PARKWAY', 'count': 5780}
# {'_id': 'BEAUTY & NAIL SALON', 'count': 5091}
# {'_id': 'AIRPORT TERMINAL', 'count': 4927}
# {'_id': 'GAS STATION', 'count': 4728}
# {'_id': 'DOCTOR/DENTIST OFFICE', 'count': 4629}
# {'_id': 'BUS (NYC TRANSIT)', 'count': 4247}
# {'_id': 'DRY CLEANER/LAUNDRY', 'count': 4172}
# {'_id': 'CONSTRUCTION SITE', 'count': 3516}
# {'_id': 'CHURCH', 'count': 3346}
# {'_id': 'TELECOMM. STORE', 'count': 2901}
# {'_id': 'OPEN AREAS (OPEN LOTS)', 'count': 2740}
# {'_id': 'VARIETY STORE', 'count': 2585}
# {'_id': 'CANDY STORE', 'count': 2466}
# {'_id': 'PRIVATE/PAROCHIAL SCHOOL', 'count': 2205}
# {'_id': 'CHECK CASHING BUSINESS', 'count': 2126}
# {'_id': 'BRIDGE', 'count': 2024}
# {'_id': 'FACTORY/WAREHOUSE', 'count': 1976}
# {'_id': 'MAILBOX OUTSIDE', 'count': 1746}
# {'_id': 'STORAGE FACILITY', 'count': 1731}
# {'_id': 'TAXI (LIVERY LICENSED)', 'count': 1724}
# {'_id': 'TAXI (YELLOW LICENSED)', 'count': 1719}
# {'_id': 'HOMELESS SHELTER', 'count': 1686}
# {'_id': 'LIQUOR STORE', 'count': 1653}
# {'_id': 'BUS STOP', 'count': 1642}
# {'_id': 'TRANSIT FACILITY (OTHER)', 'count': 1596}
# {'_id': 'ATM', 'count': 1564}
# {'_id': 'JEWELRY', 'count': 1410}
# {'_id': 'SHOE', 'count': 1302}
# {'_id': 'BUS TERMINAL', 'count': 1290}
# {'_id': 'SOCIAL CLUB/POLICY', 'count': 1153}
# {'_id': 'TUNNEL', 'count': 979}
# {'_id': 'BUS (OTHER)', 'count': 933}
# {'_id': 'MARINA/PIER', 'count': 802}
# {'_id': 'ABANDONED BUILDING', 'count': 763}
# {'_id': 'SYNAGOGUE', 'count': 711}
# {'_id': 'BOOK/CARD', 'count': 627}
# {'_id': 'VIDEO STORE', 'count': 608}
# {'_id': 'FERRY/FERRY TERMINAL', 'count': 551}
# {'_id': 'TAXI/LIVERY (UNLICENSED)', 'count': 331}
# {'_id': 'MOSQUE', 'count': 322}
# {'_id': 'OTHER HOUSE OF WORSHIP', 'count': 288}
# {'_id': 'PHOTO/COPY', 'count': 264}
# {'_id': 'MAILBOX INSIDE', 'count': 238}
# {'_id': 'CEMETERY', 'count': 224}
# {'_id': 'LOAN COMPANY', 'count': 138}
# {'_id': 'TRAMWAY', 'count': 32}
# {'_id': 'DAYCARE FACILITY', 'count': 17}

# %% [markdown]
# ### To identify patterns in suspect and victim characteristics

# %%
result = collection.aggregate([
    {"$group": {"_id": {"age": "$SUSP_AGE_GROUP", "race": "$SUSP_RACE", "sex": "$SUSP_SEX"}, "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
])

for document in result:
    print(document)
# Out:
# {'_id': {'age': 'UNKNOWN', 'race': 'UNKNOWN', 'sex': 'UNKNOWN'}, 'count': 1070367}
# {'_id': {'age': 'UNKNOWN', 'race': 'BLACK', 'sex': 'MALE'}, 'count': 109623}
# {'_id': {'age': '25-44', 'race': 'BLACK', 'sex': 'MALE'}, 'count': 98356}
# {'_id': {'age': '25-44', 'race': 'WHITE HISPANIC', 'sex': 'MALE'}, 'count': 53236}
# {'_id': {'age': 'UNKNOWN', 'race': 'UNKNOWN', 'sex': 'MALE'}, 'count': 48446}
# {'_id': {'age': 'UNKNOWN', 'race': 'WHITE HISPANIC', 'sex': 'MALE'}, 'count': 40663}
# {'_id': {'age': '18-24', 'race': 'BLACK', 'sex': 'MALE'}, 'count': 37830}
# {'_id': {'age': 'UNKNOWN', 'race': 'BLACK', 'sex': 'FEMALE'}, 'count': 37509}
# {'_id': {'age': '45-64', 'race': 'BLACK', 'sex': 'MALE'}, 'count': 34635}
# {'_id': {'age': 'UNKNOWN', 'race': 'WHITE', 'sex': 'MALE'}, 'count': 31962}
# {'_id': {'age': '25-44', 'race': 'WHITE', 'sex': 'MALE'}, 'count': 28331}
# {'_id': {'age': '25-44', 'race': 'BLACK', 'sex': 'FEMALE'}, 'count': 28170}
# {'_id': {'age': '18-24', 'race': 'WHITE HISPANIC', 'sex': 'MALE'}, 'count': 19255}
# {'_id': {'age': '25-44', 'race': 'BLACK HISPANIC', 'sex': 'MALE'}, 'count': 16298}
# {'_id': {'age': 'UNKNOWN', 'race': 'UNKNOWN', 'sex': 'FEMALE'}, 'count': 15602}
# {'_id': {'age': '45-64', 'race': 'WHITE', 'sex': 'MALE'}, 'count': 15269}
# {'_id': {'age': '45-64', 'race': 'WHITE HISPANIC', 'sex': 'MALE'}, 'count': 14836}
# {'_id': {'age': 'UNKNOWN', 'race': 'WHITE HISPANIC', 'sex': 'FEMALE'}, 'count': 14663}
# {'_id': {'age': '25-44', 'race': 'WHITE HISPANIC', 'sex': 'FEMALE'}, 'count': 14280}
# {'_id': {'age': '18-24', 'race': 'BLACK', 'sex': 'FEMALE'}, 'count': 12727}
# {'_id': {'age': 'UNKNOWN', 'race': 'BLACK HISPANIC', 'sex': 'MALE'}, 'count': 12641}
# {'_id': {'age': '<18', 'race': 'BLACK', 'sex': 'MALE'}, 'count': 10528}
# {'_id': {'age': '25-44', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'MALE'}, 'count': 10118}
# {'_id': {'age': 'UNKNOWN', 'race': 'WHITE', 'sex': 'FEMALE'}, 'count': 9963}
# {'_id': {'age': 'UNKNOWN', 'race': 'BLACK', 'sex': 'UNKNOWN'}, 'count': 9841}
# {'_id': {'age': '45-64', 'race': 'BLACK', 'sex': 'FEMALE'}, 'count': 9598}
# {'_id': {'age': '25-44', 'race': 'UNKNOWN', 'sex': 'MALE'}, 'count': 9039}
# {'_id': {'age': '25-44', 'race': 'WHITE', 'sex': 'FEMALE'}, 'count': 8826}
# {'_id': {'age': 'UNKNOWN', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'MALE'}, 'count': 7735}
# {'_id': {'age': '18-24', 'race': 'BLACK HISPANIC', 'sex': 'MALE'}, 'count': 6966}
# {'_id': {'age': '18-24', 'race': 'WHITE', 'sex': 'MALE'}, 'count': 6582}
# {'_id': {'age': '18-24', 'race': 'WHITE HISPANIC', 'sex': 'FEMALE'}, 'count': 6304}
# {'_id': {'age': '<18', 'race': 'BLACK', 'sex': 'FEMALE'}, 'count': 4531}
# {'_id': {'age': '45-64', 'race': 'WHITE', 'sex': 'FEMALE'}, 'count': 4483}
# {'_id': {'age': '45-64', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'MALE'}, 'count': 4404}
# {'_id': {'age': '<18', 'race': 'WHITE HISPANIC', 'sex': 'MALE'}, 'count': 4334}
# {'_id': {'age': '45-64', 'race': 'BLACK HISPANIC', 'sex': 'MALE'}, 'count': 4324}
# {'_id': {'age': 'UNKNOWN', 'race': 'BLACK HISPANIC', 'sex': 'FEMALE'}, 'count': 4197}
# {'_id': {'age': '45-64', 'race': 'WHITE HISPANIC', 'sex': 'FEMALE'}, 'count': 4014}
# {'_id': {'age': '25-44', 'race': 'BLACK HISPANIC', 'sex': 'FEMALE'}, 'count': 3681}
# {'_id': {'age': 'UNKNOWN', 'race': 'WHITE HISPANIC', 'sex': 'UNKNOWN'}, 'count': 3427}
# {'_id': {'age': '45-64', 'race': 'UNKNOWN', 'sex': 'MALE'}, 'count': 3163}
# {'_id': {'age': '18-24', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'MALE'}, 'count': 3150}
# {'_id': {'age': '18-24', 'race': 'UNKNOWN', 'sex': 'MALE'}, 'count': 3099}
# {'_id': {'age': '25-44', 'race': 'UNKNOWN', 'sex': 'FEMALE'}, 'count': 2866}
# {'_id': {'age': '25-44', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'FEMALE'}, 'count': 2643}
# {'_id': {'age': '18-24', 'race': 'WHITE', 'sex': 'FEMALE'}, 'count': 2313}
# {'_id': {'age': 'UNKNOWN', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'FEMALE'}, 'count': 2257}
# {'_id': {'age': 'UNKNOWN', 'race': 'WHITE', 'sex': 'UNKNOWN'}, 'count': 2237}
# {'_id': {'age': '<18', 'race': 'WHITE HISPANIC', 'sex': 'FEMALE'}, 'count': 2220}
# {'_id': {'age': '65+', 'race': 'WHITE', 'sex': 'MALE'}, 'count': 2109}
# {'_id': {'age': '65+', 'race': 'BLACK', 'sex': 'MALE'}, 'count': 2064}
# {'_id': {'age': '18-24', 'race': 'BLACK HISPANIC', 'sex': 'FEMALE'}, 'count': 1797}
# {'_id': {'age': '25-44', 'race': 'BLACK', 'sex': 'UNKNOWN'}, 'count': 1761}
# {'_id': {'age': '<18', 'race': 'BLACK HISPANIC', 'sex': 'MALE'}, 'count': 1669}
# {'_id': {'age': '<18', 'race': 'WHITE', 'sex': 'MALE'}, 'count': 1384}
# {'_id': {'age': '45-64', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'FEMALE'}, 'count': 1199}
# {'_id': {'age': 'UNKNOWN', 'race': 'BLACK HISPANIC', 'sex': 'UNKNOWN'}, 'count': 1184}
# {'_id': {'age': '65+', 'race': 'WHITE HISPANIC', 'sex': 'MALE'}, 'count': 1101}
# {'_id': {'age': '18-24', 'race': 'UNKNOWN', 'sex': 'FEMALE'}, 'count': 1075}
# {'_id': {'age': '<18', 'race': 'UNKNOWN', 'sex': 'MALE'}, 'count': 1060}
# {'_id': {'age': '45-64', 'race': 'BLACK HISPANIC', 'sex': 'FEMALE'}, 'count': 1020}
# {'_id': {'age': '45-64', 'race': 'UNKNOWN', 'sex': 'FEMALE'}, 'count': 1020}
# {'_id': {'age': 'UNKNOWN', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'MALE'}, 'count': 882}
# {'_id': {'age': '25-44', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'MALE'}, 'count': 842}
# {'_id': {'age': '25-44', 'race': 'WHITE HISPANIC', 'sex': 'UNKNOWN'}, 'count': 798}
# {'_id': {'age': '18-24', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'FEMALE'}, 'count': 781}
# {'_id': {'age': '65+', 'race': 'WHITE', 'sex': 'FEMALE'}, 'count': 747}
# {'_id': {'age': '18-24', 'race': 'BLACK', 'sex': 'UNKNOWN'}, 'count': 727}
# {'_id': {'age': '<18', 'race': 'BLACK HISPANIC', 'sex': 'FEMALE'}, 'count': 659}
# {'_id': {'age': '65+', 'race': 'BLACK', 'sex': 'FEMALE'}, 'count': 659}
# {'_id': {'age': '<18', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'MALE'}, 'count': 624}
# {'_id': {'age': '25-44', 'race': 'UNKNOWN', 'sex': 'UNKNOWN'}, 'count': 573}
# {'_id': {'age': 'UNKNOWN', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'UNKNOWN'}, 'count': 570}
# {'_id': {'age': '<18', 'race': 'WHITE', 'sex': 'FEMALE'}, 'count': 544}
# {'_id': {'age': '<18', 'race': 'UNKNOWN', 'sex': 'FEMALE'}, 'count': 509}
# {'_id': {'age': '45-64', 'race': 'BLACK', 'sex': 'UNKNOWN'}, 'count': 488}
# {'_id': {'age': '65+', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'MALE'}, 'count': 469}
# {'_id': {'age': '25-44', 'race': 'WHITE', 'sex': 'UNKNOWN'}, 'count': 462}
# {'_id': {'age': '65+', 'race': 'WHITE HISPANIC', 'sex': 'FEMALE'}, 'count': 361}
# {'_id': {'age': '45-64', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'MALE'}, 'count': 344}
# {'_id': {'age': '<18', 'race': 'BLACK', 'sex': 'UNKNOWN'}, 'count': 318}
# {'_id': {'age': '65+', 'race': 'UNKNOWN', 'sex': 'MALE'}, 'count': 308}
# {'_id': {'age': '65+', 'race': 'BLACK HISPANIC', 'sex': 'MALE'}, 'count': 306}
# {'_id': {'age': '18-24', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'MALE'}, 'count': 269}
# {'_id': {'age': 'UNKNOWN', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'FEMALE'}, 'count': 249}
# {'_id': {'age': '18-24', 'race': 'WHITE HISPANIC', 'sex': 'UNKNOWN'}, 'count': 247}
# {'_id': {'age': '25-44', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'FEMALE'}, 'count': 240}
# {'_id': {'age': '18-24', 'race': 'UNKNOWN', 'sex': 'UNKNOWN'}, 'count': 235}
# {'_id': {'age': '45-64', 'race': 'WHITE', 'sex': 'UNKNOWN'}, 'count': 219}
# {'_id': {'age': '<18', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'FEMALE'}, 'count': 217}
# {'_id': {'age': '25-44', 'race': 'BLACK HISPANIC', 'sex': 'UNKNOWN'}, 'count': 197}
# {'_id': {'age': '45-64', 'race': 'UNKNOWN', 'sex': 'UNKNOWN'}, 'count': 193}
# {'_id': {'age': '45-64', 'race': 'WHITE HISPANIC', 'sex': 'UNKNOWN'}, 'count': 175}
# {'_id': {'age': '<18', 'race': 'UNKNOWN', 'sex': 'UNKNOWN'}, 'count': 153}
# {'_id': {'age': '65+', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'FEMALE'}, 'count': 148}
# {'_id': {'age': '65+', 'race': 'UNKNOWN', 'sex': 'FEMALE'}, 'count': 131}
# {'_id': {'age': '25-44', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'UNKNOWN'}, 'count': 128}
# {'_id': {'age': '18-24', 'race': 'WHITE', 'sex': 'UNKNOWN'}, 'count': 89}
# {'_id': {'age': '18-24', 'race': 'BLACK HISPANIC', 'sex': 'UNKNOWN'}, 'count': 86}
# {'_id': {'age': '<18', 'race': 'WHITE HISPANIC', 'sex': 'UNKNOWN'}, 'count': 82}
# {'_id': {'age': 'UNKNOWN', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'UNKNOWN'}, 'count': 78}
# {'_id': {'age': '65+', 'race': 'BLACK HISPANIC', 'sex': 'FEMALE'}, 'count': 76}
# {'_id': {'age': '45-64', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'FEMALE'}, 'count': 68}
# {'_id': {'age': '18-24', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'FEMALE'}, 'count': 59}
# {'_id': {'age': '<18', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'MALE'}, 'count': 55}
# {'_id': {'age': '45-64', 'race': 'BLACK HISPANIC', 'sex': 'UNKNOWN'}, 'count': 49}
# {'_id': {'age': '18-24', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'UNKNOWN'}, 'count': 44}
# {'_id': {'age': '45-64', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'UNKNOWN'}, 'count': 42}
# {'_id': {'age': '65+', 'race': 'WHITE', 'sex': 'UNKNOWN'}, 'count': 39}
# {'_id': {'age': '65+', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'MALE'}, 'count': 34}
# {'_id': {'age': '65+', 'race': 'BLACK', 'sex': 'UNKNOWN'}, 'count': 27}
# {'_id': {'age': '65+', 'race': 'UNKNOWN', 'sex': 'UNKNOWN'}, 'count': 25}
# {'_id': {'age': '<18', 'race': 'BLACK HISPANIC', 'sex': 'UNKNOWN'}, 'count': 24}
# {'_id': {'age': '<18', 'race': 'WHITE', 'sex': 'UNKNOWN'}, 'count': 23}
# {'_id': {'age': '<18', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'UNKNOWN'}, 'count': 17}
# {'_id': {'age': '65+', 'race': 'WHITE HISPANIC', 'sex': 'UNKNOWN'}, 'count': 16}
# {'_id': {'age': '<18', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'FEMALE'}, 'count': 15}
# {'_id': {'age': '25-44', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'UNKNOWN'}, 'count': 14}
# {'_id': {'age': '65+', 'race': 'ASIAN / PACIFIC ISLANDER', 'sex': 'UNKNOWN'}, 'count': 9}
# {'_id': {'age': '45-64', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'UNKNOWN'}, 'count': 7}
# {'_id': {'age': '65+', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'FEMALE'}, 'count': 5}
# {'_id': {'age': '18-24', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'UNKNOWN'}, 'count': 4}
# {'_id': {'age': '65+', 'race': 'BLACK HISPANIC', 'sex': 'UNKNOWN'}, 'count': 3}
# {'_id': {'age': '45-64', 'race': 'OTHER', 'sex': 'MALE'}, 'count': 1}
# {'_id': {'age': '<18', 'race': 'AMERICAN INDIAN/ALASKAN NATIVE', 'sex': 'UNKNOWN'}, 'count': 1}
# {'_id': {'age': 'UNKNOWN', 'race': 'OTHER', 'sex': 'MALE'}, 'count': 1}

# %% [markdown]
# ### To identify clearance rates for different types of crimes, precincts, or boroughs:

# %%
result = collection.aggregate([
    {"$match": {"CRM_ATPT_CPTD_CD": "COMPLETED"}},
    {"$group": {"_id": {"offense": "$OFNS_DESC", "borough": "$BORO_NM", "year": {"$year": {"$dateFromString": {"dateString": "$CMPLNT_FR_DT"}}}}, "count": {"$sum": 1}}},
    {"$sort": {"_id.offense": 1}}
])

for document in result:
    print(document)
# Out:
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BRONX', 'year': 1998}, 'count': 1}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'QUEENS', 'year': 2007}, 'count': 75}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'QUEENS', 'year': 2005}, 'count': 1}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'QUEENS', 'year': 2009}, 'count': 78}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'QUEENS', 'year': 2015}, 'count': 77}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2012}, 'count': 16}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'QUEENS', 'year': 2013}, 'count': 74}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2006}, 'count': 11}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BRONX', 'year': 2014}, 'count': 48}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2008}, 'count': 16}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BROOKLYN', 'year': 2006}, 'count': 106}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BRONX', 'year': 2012}, 'count': 59}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2010}, 'count': 28}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2014}, 'count': 8}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BRONX', 'year': 2006}, 'count': 60}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2016}, 'count': 14}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2018}, 'count': 13}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2020}, 'count': 15}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'MANHATTAN', 'year': 2012}, 'count': 36}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BRONX', 'year': 2018}, 'count': 70}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BROOKLYN', 'year': 2012}, 'count': 98}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BROOKLYN', 'year': 1962}, 'count': 1}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BROOKLYN', 'year': 2010}, 'count': 91}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'STATEN ISLAND', 'year': 2017}, 'count': 11}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'BRONX', 'year': 2016}, 'count': 60}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 

# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'MANHATTAN', 'year': 2007}, 'count': 40}
# {'_id': {'offense': 'ADMINISTRATIVE CODE', 'borough': 'QUEENS', 'year': 2016}, 'count': 56}
# {'_id': {'offense': 'ADMINISTRATIVE CODES', 'borough': 'BROOKLYN', 'year': 2008}, 'count': 1}
# {'_id': {'offense': 'ADMINISTRATIVE CODES', 'borough': 'BROOKLYN', 'year': 2015}, 'count': 1}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'QUEENS', 'year': 2021}, 'count': 3}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2021}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'QUEENS', 'year': 2019}, 'count': 7}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'QUEENS', 'year': 2017}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'QUEENS', 'year': 2015}, 'count': 7}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BRONX', 'year': 2018}, 'count': 6}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2021}, 'count': 9}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BRONX', 'year': 2020}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2015}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2017}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2019}, 'count': 7}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2015}, 'count': 3}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2017}, 'count': 7}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2019}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BRONX', 'year': 2016}, 'count': 8}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'STATEN ISLAND', 'year': 2017}, 'count': 6}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'STATEN ISLAND', 'year': 2015}, 'count': 2}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'STATEN ISLAND', 'year': 2021}, 'count': 1}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'STATEN ISLAND', 'year': 2019}, 'count': 1}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'QUEENS', 'year': 2018}, 'count': 8}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'QUEENS', 'year': 2016}, 'count': 6}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BRONX', 'year': 2019}, 'count': 8}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BRONX', 'year': 2021}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2016}, 'count': 6}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2020}, 'count': 7}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2016}, 'count': 8}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BROOKLYN', 'year': 2018}, 'count': 7}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2018}, 'count': 5}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'MANHATTAN', 'year': 2020}, 'count': 4}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'borough': 'BRONX', 'year': 2015}, 'count': 14}
# {'_id': {'offense': 'AGRICULTURE & MRKTS LAW-UNCLASSIFI

# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'MANHATTAN', 'year': 2012}, 'count': 8}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'MANHATTAN', 'year': 2014}, 'count': 2}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'BRONX', 'year': 2012}, 'count': 4}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'BRONX', 'year': 2018}, 'count': 12}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'BRONX', 'year': 2016}, 'count': 10}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'QUEENS', 'year': 2008}, 'count': 4}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'BRONX', 'year': 2006}, 'count': 9}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'QUEENS', 'year': 2006}, 'count': 1}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'MANHATTAN', 'year': 2010}, 'count': 7}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'BRONX', 'year': 2010}, 'count': 13}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'MANHATTAN', 'year': 2008}, 'count': 2}
# {'_id': {'offense': 'ALCOHOLIC BEVERAGE CONTROL LAW', 'borough': 'BRONX', 'year': 2008}, 'count': 10}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BRONX', 'year': 2021}, 'count': 4}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BROOKLYN', 'year': 2019}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BROOKLYN', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BROOKLYN', 'year': 2007}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'MANHATTAN', 'year': 2012}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BRONX', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'MANHATTAN', 'year': 2011}, 'count': 2}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'MANHATTAN', 'year': 2019}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'QUEENS', 'year': 2015}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'QUEENS', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'QUEENS', 'year': 2019}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BRONX', 'year': 2010}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BRONX', 'year': 2012}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BRONX', 'year': 2008}, 'count': 2}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BROOKLYN', 'year': 2018}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BROOKLYN', 'year': 2010}, 'count': 2}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BRONX', 'year': 2020}, 'count': 2}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'BROOKLYN', 'year': 2006}, 'count': 3}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'MANHATTAN', 'year': 2009}, 'count': 2}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'MANHATTAN', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'ANTICIPATORY OFFENSES', 'borough': 'MANHATTAN', 'year': 2010}, 'count': 1}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2018}, 'count': 9}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2020}, 'count': 5}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2012}, 'count': 12}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2021}, 'count': 34}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2010}, 'count': 26}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2017}, 'count': 50}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2019}, 'count': 28}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2019}, 'count': 57}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2007}, 'count': 65}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2015}, 'count': 93}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2006}, 'count': 47}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2009}, 'count': 131}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2016}, 'count': 14}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2011}, 'count': 100}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2014}, 'count': 15}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2006}, 'count': 25}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2015}, 'count': 50}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2009}, 'count': 43}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2008}, 'count': 30}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2013}, 'count': 95}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2017}, 'count': 49}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2012}, 'count': 43}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2007}, 'count': 96}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2014}, 'count': 37}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2013}, 'count': 83}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2019}, 'count': 48}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2018}, 'count': 32}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2020}, 'count': 33}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2009}, 'count': 99}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2005}, 'count': 8}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2007}, 'count': 151}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2005}, 'count': 3}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2011}, 'count': 80}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2017}, 'count': 27}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2021}, 'count': 43}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2021}, 'count': 27}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2015}, 'count': 82}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2009}, 'count': 55}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2011}, 'count': 43}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2013}, 'count': 44}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2015}, 'count': 48}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2019}, 'count': 7}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2021}, 'count': 4}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2011}, 'count': 15}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2016}, 'count': 55}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2013}, 'count': 25}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2018}, 'count': 52}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2014}, 'count': 88}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2008}, 'count': 172}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2008}, 'count': 88}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2010}, 'count': 146}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2017}, 'count': 8}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2005}, 'count': 3}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2007}, 'count': 51}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2020}, 'count': 65}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2015}, 'count': 12}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2006}, 'count': 78}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2016}, 'count': 47}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2010}, 'count': 59}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2009}, 'count': 12}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2012}, 'count': 107}
# {'_id': {'offense': 'ARSON', 'borough': 'STATEN ISLAND', 'year': 2007}, 'count': 17}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2013}, 'count': 50}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2008}, 'count': 123}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2012}, 'count': 38}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2006}, 'count': 104}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2017}, 'count': 29}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2020}, 'count': 64}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2011}, 'count': 46}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2018}, 'count': 44}
# {'_id': {'offense': 'ARSON', 'borough': 'BROOKLYN', 'year': 2006}, 'count': 142}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2010}, 'count': 102}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2019}, 'count': 30}
# {'_id': {'offense': 'ARSON', 'borough': 'QUEENS', 'year': 2021}, 'count': 37}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2012}, 'count': 79}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2016}, 'count': 33}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2018}, 'count': 36}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2020}, 'count': 34}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2016}, 'count': 53}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2010}, 'count': 60}
# {'_id': {'offense': 'ARSON', 'borough': 'BRONX', 'year': 2014}, 'count': 100}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2014}, 'count': 43}
# {'_id': {'offense': 'ARSON', 'borough': 'MANHATTAN', 'year': 2008}, 'count': 59}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BROOKLYN', 'year': 2002}, 'count': 1}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'QUEENS', 'year': 2007}, 'count': 2556}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BROOKLYN', 'year': 2004}, 'count': 3}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BRONX', 'year': 2010}, 'count': 3160}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'QUEENS', 'year': 2005}, 'count': 7}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BROOKLYN', 'year': 2006}, 'count': 4248}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BRONX', 'year': 2016}, 'count': 3336}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'STATEN ISLAND', 'year': 2007}, 'count': 550}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'QUEENS', 'year': 2011}, 'count': 2537}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BROOKLYN', 'year': 2008}, 'count': 4084}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'BRONX', 'year': 2006}, 'count': 2798}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'STATEN ISLAND', 'year': 2009}, 'count': 576}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'QUEENS', 'year': 2009}, 'count': 2486}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'QUEENS', 'year': 2015}, 'count': 2583}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'STATEN ISLAND', 'year': 2017}, 'count': 506}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 'MANHATTAN', 'year': 2017}, 'count': 2575}
# {'_id': {'offense': 'ASSAULT 3 & RELATED OFFENSES', 'borough': 

# {'_id': {'offense': "BURGLAR'S TOOLS", 'borough': 'BRONX', 'year': 2013}, 'count': 4}
# {'_id': {'offense': "BURGLAR'S TOOLS", 'borough': 'BRONX', 'year': 2007}, 'count': 3}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BROOKLYN', 'year': 2017}, 'count': 952}
# {'_id': {'offense': 'BURGLARY', 'borough': 'STATEN ISLAND', 'year': 2005}, 'count': 1}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BRONX', 'year': 2010}, 'count': 737}
# {'_id': {'offense': 'BURGLARY', 'borough': 'STATEN ISLAND', 'year': 2015}, 'count': 124}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BROOKLYN', 'year': 2015}, 'count': 1293}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BRONX', 'year': 2012}, 'count': 742}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 2008}, 'count': 955}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BRONX', 'year': 2014}, 'count': 694}
# {'_id': {'offense': 'BURGLARY', 'borough': 'STATEN ISLAND', 'year': 2009}, 'count': 139}
# {'_id': {'offense': 'BURGLARY', 'borough': 'QUEENS', 'year': 2010}, 'count': 1118}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BROOKLYN', 'year': 2013}, 'count': 1364}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 2006}, 'count': 1107}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BRONX', 'year': 2016}, 'count': 597}
# {'_id': {'offense': 'BURGLARY', 'borough': 'QUEENS', 'year': 2008}, 'count': 1266}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BROOKLYN', 'year': 2011}, 'count': 1498}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 2004}, 'count': 1}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BRONX', 'year': 2018}, 'count': 529}
# {'_id': {'offense': 'BURGLARY', 'borough': 'STATEN ISLAND', 'year': 2007}, 'count': 199}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 2002}, 'count': 1}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BRONX', 'year': 2020}, 'count': 615}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 1966}, 'count': 1}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 2016}, 'count': 563}
# {'_id': {'offense': 'BURGLARY', 'borough': 'BROOKLYN', 'year': 2019}, 'count': 856}
# {'_id': {'offense': 'BURGLARY', 'borough': 'MANHATTAN', 'year': 2014}, 'count': 687}
# ...
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2012}, 'count': 61}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2014}, 'count': 56}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2016}, 'count': 50}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2018}, 'count': 64}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2005}, 'count': 1}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2009}, 'count': 31}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2007}, 'count': 22}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2014}, 'count': 30}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2012}, 'count': 26}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 1018}, 'count': 1}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2018}, 'count': 21}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2016}, 'count': 20}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2007}, 'count': 95}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2005}, 'count': 4}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2006}, 'count': 34}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2001}, 'count': 1}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2012}, 'count': 98}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2008}, 'count': 43}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2021}, 'count': 90}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2019}, 'count': 122}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2010}, 'count': 112}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2013}, 'count': 111}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2016}, 'count': 135}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2017}, 'count': 145}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2012}, 'count': 102}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2013}, 'count': 117}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2017}, 'count': 127}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2018}, 'count': 48}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2014}, 'count': 49}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 2010}, 'count': 104}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2020}, 'count': 42}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2016}, 'count': 50}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2010}, 'count': 45}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2021}, 'count': 78}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2007}, 'count': 96}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BROOKLYN', 'year': 2005}, 'count': 3}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'MANHATTAN', 'year': 2012}, 'count': 45}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2005}, 'count': 1}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2007}, 'count': 66}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2009}, 'count': 32}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2017}, 'count': 78}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2008}, 'count': 23}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2011}, 'count': 48}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2019}, 'count': 50}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2021}, 'count': 55}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2015}, 'count': 49}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2006}, 'count': 31}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2020}, 'count': 18}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2004}, 'count': 1}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'QUEENS', 'year': 1971}, 'count': 1}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'STATEN ISLAND', 'year': 2010}, 'count': 27}
# {'_id': {'offense': 'UNAUTHORIZED USE OF A VEHICLE', 'borough': 'BRONX', 'year': 2013}, 'count': 55}
# {'_id': {'offense': 'UNDER THE INFLUENCE OF DRUGS', 'borough': 'MANHATTAN', 'year': 2009}, 'count': 1}
# {'_id': {'offense': 'UNDER THE INFLUENCE OF DRUGS', 'borough': 'STATEN ISLAND', 'year': 2015}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'QUEENS', 'year': 2012}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BROOKLYN', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BROOKLYN', 'year': 2006}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'MANHATTAN', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BROOKLYN', 'year': 2010}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BRONX', 'year': 2010}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'QUEENS', 'year': 2011}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'MANHATTAN', 'year': 2019}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'QUEENS', 'year': 2019}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BROOKLYN', 'year': 2012}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BRONX', 'year': 2020}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'QUEENS', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BROOKLYN', 'year': 2018}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BRONX', 'year': 2011}, 'count': 3}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'MANHATTAN', 'year': 2014}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'BRONX', 'year': 2013}, 'count': 1}
# {'_id': {'offense': 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'borough': 'MANHATTAN', 'year': 2008}, 'count': 1}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2021}, 'count': 506}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2009}, 'count': 31}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'BRONX', 'year': 2010}, 'count': 484}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2019}, 'count': 464}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2001}, 'count': 1}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'BRONX', 'year': 2008}, 'count': 317}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2019}, 'count': 34}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2017}, 'count': 429}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2019}, 'count': 301}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2017}, 'count': 49}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2015}, 'count': 495}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2017}, 'count': 259}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2013}, 'count': 428}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2015}, 'count': 48}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2011}, 'count': 449}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2013}, 'count': 276}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2013}, 'count': 46}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2011}, 'count': 42}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2011}, 'count': 250}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2009}, 'count': 340}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2009}, 'count': 320}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'QUEENS', 'year': 2007}, 'count': 257}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'BROOKLYN', 'year': 2009}, 'count': 380}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'STATEN ISLAND', 'year': 2007}, 'count': 31}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2007}, 'count': 406}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'BROOKLYN', 'year': 2007}, 'count': 331}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 'MANHATTAN', 'year': 2005}, 'count': 4}
# {'_id': {'offense': 'VEHICLE AND TRAFFIC LAWS', 'borough': 